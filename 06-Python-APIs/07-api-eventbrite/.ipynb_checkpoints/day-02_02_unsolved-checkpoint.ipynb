# %%
# Dependencies requests, pandas as "pd", pprint as pprint,
    # and your config file for api_key
    # Note: For the api_key check the "App Management" tab
        # You'll want to use the "Anonymous access OAuth token" or "Your personal OAuth token"
import json
import requests
import pprint as pp
import pandas as pd
import numpy as np
from config import api_key

# %%
# Update panda's max column with by reviewing the following documentation.
    # This will be important later when dealing with larger columns.

# %%
# Set the url and query information for eventbrite
    # Check out www.eventbriteapi.com to review how to create queries.
    # Query for the following information:
        # url is "https://www.eventbriteapi.com/v3/events/search/?q="
            # Please review documentation to get the base url for searching events.
                # https://www.eventbrite.com/developer/v3/quickstart/
                # https://www.eventbrite.com/developer/v3/endpoints/events/#ebapi-get-events-search
            # If still stuck, check 'hint.txt' for base url
        # price is "free"
        # event's name is "meetup"
        # location is "san francisco"
url = "https://www.eventbriteapi.com/v3/events/search/?q="
price = "free"
location = "san francisco"

# Build query URL with the parameters mentioned above and api_key.
    # Don't forget to check documentation from link mentioned above for event searching.
q_url = f"{url}price={price}&location.address={location}&token={api_key}"
# Out:
# {'pagination': {'object_count': 116,
#   'page_number': 1,
#   'page_size': 50,
#   'page_count': 3,
#   'has_more_items': True},
#  'events': [{'name': {'text': 'Product Marketing Workshop: Building a SaaS Pricing and Packaging Foundation for Growth',
#     'html': 'Product Marketing Workshop: Building a SaaS Pricing and Packaging Foundation for Growth'},
#    'description': {'text': 'Join us for a crash course on SaaS Pricing and Packaging. We’ll be going through the fundamentals of product packaging, the pros, and cons of different pricing models, and diagnose real-world examples. Understand how to take methodology and put it to practice with your Sales team.We’ll cover topics such as:· Creating the right value levers and packaging to maximize revenue· Partnering with Sales on deal strategy and value selling· Evaluating and measuring the health of your current pricing model\nAbout the instructor:\xa0\nJohnny Cheng:\xa0https://www.linkedin.com/in/jdcheng/\nJohnny Cheng is the Director of Product Marketing, Pricing and Packaging at Gainsight. He has 10+ years of Product Marketing and Business Analyst experience in the tech industry. His specialization is SaaS Pricing, which he’s lead at several companies including Marketo. He’s a self-proclaimed Mathlete and loves to create Excel charts in his free time.\n',
#     'html': '<P><SPAN>Join us for a crash course on SaaS Pricing and Packaging. We’ll be going through the fundamentals of product packaging, the pros, and cons of different pricing models, and diagnose real-world examples. Understand how to take methodology and put it to practice with your Sales team.</SPAN><BR><BR><SPAN>We’ll cover topics such as:</SPAN><BR><BR><SPAN>· Creating the right value levers and packaging to maximize revenue</SPAN><BR><BR><SPAN>· Partnering with Sales on deal strategy and value selling</SPAN><BR><BR><SPAN>· Evaluating and measuring the health of your current pricing model</SPAN><BR><SPAN></SPAN></P>\n<P><STRONG>About the instructor:\xa0</STRONG></P>\n<P>Johnny Cheng:\xa0<A CLASS="link" HREF="https://www.linkedin.com/in/jdcheng/" TARGET="__blank" TITLE="https://www.linkedin.com/in/jdcheng/" REL="nofollow">https://www.linkedin.com/in/jdcheng/</A></P>\n<P><SPAN>Johnny Cheng is the Director of Product Marketing, Pricing and Packaging at Gainsight. He has 10+ years of Product Marketing and Business Analyst experience in the tech industry. His specialization is SaaS Pricing, which he’s lead at several companies including Marketo. He’s a self-proclaimed Mathlete and loves to create Excel charts in his free time.</SPAN></P>\n<P><SPAN><IMG SRC="https://cdn.evbuc.com/eventlogos/152288202/headshot-1.jpg"></SPAN></P>'},
#    'id': '50554218027',
#    'url': 'https://www.eventbrite.com/e/product-marketing-workshop-building-a-saas-pricing-and-packaging-foundation-for-growth-tickets-50554218027?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-15T19:00:00',
#     'utc': '2018-10-16T02:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-15T22:00:00',
#     'utc': '2018-10-16T05:00:00Z'},
#    'organization_id': '153354219414',
#    'created': '2018-09-22T05:01:02Z',
#    'changed': '2018-09-28T00:20:47Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 600,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': False,
#    'version': '3.0.0',
#    'logo_id': '50202705',
#    'organizer_id': '17485975975',
#    'venue_id': '26940299',
#    'category_id': '101',
#    'subcategory_id': '1007',
#    'format_id': '9',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50554218027/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 20},
#      'width': 866,
#      'height': 433},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50202705%2F153354219414%2F1%2Foriginal.jpg?auto=compress&s=081556d2644deca640fed2844552d7b4',
#      'width': 867,
#      'height': 475},
#     'id': '50202705',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50202705%2F153354219414%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C20%2C866%2C433&s=b2a4b42b001ed38418ee08585a4a5c8c',
#     'aspect_ratio': '2',
#     'edge_color': None,
#     'edge_color_set': True}},
#   {'name': {'text': 'Sports Basement Free CPR Class in San Francisco',
#     'html': 'Sports Basement Free CPR Class in San Francisco'},
#    'description': {'text': 'FREE CPR Class by Sports Basement\nCourse Name:\xa0STS CPRDescription: CPR for adults, children, and infants, AED use, choke-savingLength:\xa02 hoursCourse Price:\xa0$0Cancellation Policy: Please let us know if you want to cancel, so we can give your spot to someone else.\nCertificationThis course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our website for courses and prices.\xa0\xa0This course is for those who do not require an official certification card.\nWho should\xa0NOT\xa0take this CPR classMedical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take Pediatric First-aid/CPR course.\nFree Keychain CPR Breathing Mask ($10 value)On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.\nClassroomChildren are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.\nQuestions?Give us a call at 415-437-1600',
#     'html': '<H2><STRONG>FREE CPR Class by Sports Basement</STRONG></H2>\n<P CLASS="p1"><STRONG>Course Name</STRONG>:\xa0STS CPR<BR><STRONG>Description:</STRONG> CPR for adults, children, and infants, AED use, choke-saving<BR><STRONG>Length:</STRONG>\xa02 hours<BR><STRONG>Course Price</STRONG>:\xa0$0<BR><STRONG>Cancellation Policy:</STRONG> Please let us know if you want to cancel, so we can give your spot to someone else.<BR></P>\n<P CLASS="p1"><STRONG>Certification</STRONG><BR>This course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our <A HREF="http://www.bayareacpr.org" TARGET="_blank" TITLE="Bay Area American Heart Association" REL="noreferrer noopener nofollow noopener noreferrer nofollow">website</A> for courses and prices.\xa0<SPAN CLASS="Apple-converted-space">\xa0</SPAN>This course is for those who do not require an official certification card.</P>\n<P CLASS="p1"><STRONG>Who should\xa0<SPAN CLASS="s1">NOT</SPAN>\xa0take this CPR class</STRONG><BR>Medical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take Pediatric First-aid/CPR course.</P>\n<P CLASS="p4"><STRONG>Free Keychain CPR Breathing Mask ($10 value)</STRONG><BR>On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.</P>\n<P CLASS="p4"><STRONG>Classroom</STRONG><BR>Children are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.</P>\n<P><STRONG>Questions?</STRONG><BR>Give us a call at 415-437-1600</P>'},
#    'id': '50658880074',
#    'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50658880074?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2019-01-15T09:00:00',
#     'utc': '2019-01-15T17:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2019-01-15T11:00:00',
#     'utc': '2019-01-15T19:00:00Z'},
#    'organization_id': '14268435757',
#    'created': '2018-09-25T18:43:03Z',
#    'changed': '2018-09-25T18:43:53Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '50351711',
#    'organizer_id': '1086926597',
#    'venue_id': '974499',
#    'category_id': '107',
#    'subcategory_id': '7003',
#    'format_id': '9',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50658880074/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 106},
#      'width': 2120,
#      'height': 1060},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351711%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=554e8b37e59fb4a91b18fc667b287fb5',
#      'width': 2121,
#      'height': 1414},
#     'id': '50351711',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351711%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=01d9910b9d3546b4bd7ae5346a86bb78',
#     'aspect_ratio': '2',
#     'edge_color': '#ddd7d2',
#     'edge_color_set': True}},
#   {'name': {'text': 'Sports Basement Free CPR Class in San Francisco',
#     'html': 'Sports Basement Free CPR Class in San Francisco'},
#    'description': {'text': 'FREE CPR Class by Sports Basement\nCourse Name:\xa0STS CPRDescription: CPR for adults, children, and infants, AED use, choke-savingLength:\xa02 hoursCourse Price:\xa0$0Cancellation Policy: Please let us know if you want to cancel, so we can give your spot to someone else.\nCertificationThis course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our website for courses and prices.\xa0\xa0This course is for those who do not require an official certification card.\nWho should\xa0NOT\xa0take this CPR classMedical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take the Pediatric First-aid/CPR course.\nFree Keychain CPR Breathing Mask ($10 value)On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.\nClassroomChildren are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.\nQuestions?Give us a call at 415-437-1600',
#     'html': '<H2><STRONG>FREE CPR Class by Sports Basement</STRONG></H2>\n<P CLASS="p1"><STRONG>Course Name</STRONG>:\xa0STS CPR<BR><STRONG>Description:</STRONG> CPR for adults, children, and infants, AED use, choke-saving<BR><STRONG>Length:</STRONG>\xa02 hours<BR><STRONG>Course Price</STRONG>:\xa0$0<BR><STRONG>Cancellation Policy:</STRONG> Please let us know if you want to cancel, so we can give your spot to someone else.<BR></P>\n<P CLASS="p1"><STRONG>Certification</STRONG><BR>This course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our <A HREF="http://www.bayareacpr.org" TARGET="_blank" TITLE="Bay Area American Heart Association" REL="noreferrer noopener nofollow noopener noreferrer nofollow">website</A> for courses and prices.\xa0<SPAN CLASS="Apple-converted-space">\xa0</SPAN>This course is for those who do not require an official certification card.</P>\n<P CLASS="p1"><STRONG>Who should\xa0<SPAN CLASS="s1">NOT</SPAN>\xa0take this CPR class</STRONG><BR>Medical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take the Pediatric First-aid/CPR course.</P>\n<P CLASS="p4"><STRONG>Free Keychain CPR Breathing Mask ($10 value)</STRONG><BR>On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.</P>\n<P CLASS="p4"><STRONG>Classroom</STRONG><BR>Children are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.</P>\n<P><STRONG>Questions?</STRONG><BR>Give us a call at 415-437-1600</P>'},
#    'id': '50657163941',
#    'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50657163941?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-12-25T09:00:00',
#     'utc': '2018-12-25T17:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-12-25T11:00:00',
#     'utc': '2018-12-25T19:00:00Z'},
#    'organization_id': '14268435757',
#    'created': '2018-09-25T18:17:10Z',
#    'changed': '2018-09-25T20:24:13Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '50349672',
#    'organizer_id': '1086926597',
#    'venue_id': '974499',
#    'category_id': '107',
#    'subcategory_id': '7003',
#    'format_id': '9',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50657163941/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 106},
#      'width': 2120,
#      'height': 1060},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50349672%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=7dc423cb8aded7c260417cf8029876d1',
#      'width': 2121,
#      'height': 1414},
#     'id': '50349672',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50349672%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=9390581ae234be7e3f30723abaf73f33',
#     'aspect_ratio': '2',
#     'edge_color': '#ddd7d2',
#     'edge_color_set': True}},
#   {'name': {'text': 'Sports Basement Free CPR Class in San Francisco',
#     'html': 'Sports Basement Free CPR Class in San Francisco'},
#    'description': {'text': 'FREE CPR Class by Sports Basement\nCourse Name:\xa0STS CPRDescription: CPR for adults, children, and infants, AED use, choke-savingLength:\xa02 hoursCourse Price:\xa0$0Cancellation Policy: Please let us know if you want to cancel, so we can give your spot to someone else.\nCertificationThis course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our website for courses and prices.\xa0\xa0This course is for those who do not require an official certification card.\nWho should\xa0NOT\xa0take this CPR classMedical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take Pediatric First-aid/CPR course.\nFree Keychain CPR Breathing Mask ($10 value)On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.\nClassroomChildren are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.\nQuestions?Give us a call at 415-437-1600',
#     'html': '<H2><STRONG>FREE CPR Class by Sports Basement</STRONG></H2>\n<P CLASS="p1"><STRONG>Course Name</STRONG>:\xa0STS CPR<BR><STRONG>Description:</STRONG> CPR for adults, children, and infants, AED use, choke-saving<BR><STRONG>Length:</STRONG>\xa02 hours<BR><STRONG>Course Price</STRONG>:\xa0$0<BR><STRONG>Cancellation Policy:</STRONG> Please let us know if you want to cancel, so we can give your spot to someone else.<BR></P>\n<P CLASS="p1"><STRONG>Certification</STRONG><BR>This course is not by the American Heart Association or the American Red Cross. If you need to have an official certification card for a work requirement, you would need to take an American Heart Association course. View our <A HREF="http://www.bayareacpr.org" TARGET="_blank" TITLE="Bay Area American Heart Association" REL="noreferrer noopener nofollow noopener noreferrer nofollow">website</A> for courses and prices.\xa0<SPAN CLASS="Apple-converted-space">\xa0</SPAN>This course is for those who do not require an official certification card.</P>\n<P CLASS="p1"><STRONG>Who should\xa0<SPAN CLASS="s1">NOT</SPAN>\xa0take this CPR class</STRONG><BR>Medical or healthcare professionals must take the BLS class. Childcare providers who need EMSA certification must take Pediatric First-aid/CPR course.</P>\n<P CLASS="p4"><STRONG>Free Keychain CPR Breathing Mask ($10 value)</STRONG><BR>On the day of your class, you can check in with your mobile phone on Facebook, Foursquare, or Yelp and receive a free keychain CPR mask.</P>\n<P CLASS="p4"><STRONG>Classroom</STRONG><BR>Children are not allowed in the classroom. For your convenience we offer free tea, granola bars, and a phone charging station.</P>\n<P><STRONG>Questions?</STRONG><BR>Give us a call at 415-437-1600</P>'},
#    'id': '50659001437',
#    'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50659001437?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2019-02-15T09:00:00',
#     'utc': '2019-02-15T17:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2019-02-15T11:00:00',
#     'utc': '2019-02-15T19:00:00Z'},
#    'organization_id': '14268435757',
#    'created': '2018-09-25T18:44:14Z',
#    'changed': '2018-09-25T18:44:35Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '50351797',
#    'organizer_id': '1086926597',
#    'venue_id': '974499',
#    'category_id': '107',
#    'subcategory_id': '7003',
#    'format_id': '9',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50659001437/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 106},
#      'width': 2120,
#      'height': 1060},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351797%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=6a6932b60e54d3ca854e39e06cbf7d8f',
#      'width': 2121,
#      'height': 1414},
#     'id': '50351797',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351797%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=f774becba1a31a7c1d2f6c1ca0288d0f',
#     'aspect_ratio': '2',
#     'edge_color': '#ddd7d2',
#     'edge_color_set': True}},
#   {'name': {'text': 'STARTUP BASECAMP: FREE CO-WORKING PASS',
#     'html': 'STARTUP BASECAMP: FREE CO-WORKING PASS'},
#    'description': {'text': "Looking for a new space to work from for the day? Calling entrepreneurs, hackers, digital nomads, and startup founders to join us at\xa0Startup Basecamp's community space\xa0for our weekly\xa0FREE COWORKING PASS.\xa0\nSTARTUP BASECAMP is the first Startup Hotel offering a unique short-term co-living & co-working solution in San Francisco for startup professionals and entrepreneurs.\xa0\nThere's hot coffee, high-speed wifi, and a great group of like-minded people ready to connect.\xa0Our innovative community of entrepreneurs is diverse and international, giving you the chance to meet and collaborate with people from across the globe.\xa0\nWork indoors or catch some fun & sun in our cool outdoor lounge!\xa0\nSpace is limited so we kindly ask you to RSVP and you update your\xa0RSVP if your plans change and you can no longer make it :)\xa0\n\nABOUT STARTUP BASECAMP:\nAs the\xa0First Startup Hotel in San Francisco\xa0& an industry leader in the space\xa0-\xa0Startup Basecamp\xa0pioneered the concept of a\xa0CO-LIVING & CO-WORKING HOTEL providing\xa0a quality short-term solution for startup\xa0professionals and\xa0entrepreneurs looking for both a reasonably priced place to stay and a supportive community while they visit Silicon Valley.\nJOIN OUR COMMUNITY\xa0TODAY!",
#     'html': '<P>Looking for a new space to work from for the day? Calling entrepreneurs, hackers, digital nomads, and startup founders to join us at\xa0Startup Basecamp\'s community space\xa0for our weekly\xa0<STRONG>FREE COWORKING PASS.\xa0</STRONG></P>\n<P><STRONG>STARTUP BASECAMP is the first Startup Hotel offering a unique short-term co-living &amp; co-working solution in San Francisco for startup professionals and entrepreneurs.\xa0</STRONG></P>\n<P>There\'s hot coffee, high-speed wifi, and a great group of like-minded people ready to connect.\xa0Our innovative community of entrepreneurs is diverse and international, giving you the chance to meet and collaborate with people from across the globe.\xa0</P>\n<P>Work indoors or catch some fun &amp; sun in our cool outdoor lounge!\xa0</P>\n<P><STRONG>Space is limited so we kindly ask you to RSVP and you update your\xa0RSVP if your plans change and you can no longer make it :)\xa0</STRONG></P>\n<P><IMG SRC="https://cdn.evbuc.com/eventlogos/179582397/collagesbc.jpg"></P>\n<P><STRONG>ABOUT STARTUP BASECAMP:</STRONG></P>\n<P>As the<STRONG>\xa0First Startup Hotel in San Francisco\xa0</STRONG>&amp; an industry leader in the space\xa0<STRONG>-\xa0</STRONG><STRONG><A HREF="https://www.eventbrite.com/e/silicon-valley-survival-program-tickets-26476289294" TARGET="_blank" REL="noopener noreferrer noopener noreferrer">Startup Basecamp</A>\xa0</STRONG>pioneered the concept of a\xa0<STRONG>CO-LIVING &amp; CO-WORKING HOTEL </STRONG>providing\xa0a quality short-term solution for startup\xa0professionals and\xa0entrepreneurs looking for both a reasonably priced place to stay and a supportive community while they visit Silicon Valley.</P>\n<P><STRONG><A HREF="http://www.startupbasecamp.org/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">JOIN OUR COMMUNITY</A>\xa0TODAY!</STRONG></P>'},
#    'id': '50504043955',
#    'url': 'https://www.eventbrite.com/e/startup-basecamp-free-co-working-pass-tickets-50504043955?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-11T09:30:00',
#     'utc': '2018-10-11T16:30:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-11T18:30:00',
#     'utc': '2018-10-12T01:30:00Z'},
#    'organization_id': '180839473779',
#    'created': '2018-09-20T19:21:57Z',
#    'changed': '2018-09-26T17:27:00Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': True,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '44682865',
#    'organizer_id': '10966312574',
#    'venue_id': '17318909',
#    'category_id': '101',
#    'subcategory_id': '1001',
#    'format_id': '10',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50504043955/',
#    'is_externally_ticketed': False,
#    'series_id': '45958274436',
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 241},
#      'width': 2048,
#      'height': 1024},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44682865%2F180839473779%2F1%2Foriginal.jpg?auto=compress&s=eba5d78b1563551e3761028075d09922',
#      'width': 2048,
#      'height': 1365},
#     'id': '44682865',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44682865%2F180839473779%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C241%2C2048%2C1024&s=92739948f4bf77721e164034788a1d8f',
#     'aspect_ratio': '2',
#     'edge_color': '#73513c',
#     'edge_color_set': True}},
#   {'name': {'text': 'Free Outdoor Class: Intro to Light Saber Combat',
#     'html': 'Free Outdoor Class: Intro to Light Saber Combat'},
#    'description': {'text': "Learn to Wield a Light Saber!\nAt LudoSport, we teach students how to do actual improvisational sparring with light sabers (no choreography here!). With practice, students are able to safely duel with one another, and even eventually compete in official LudoSport tournaments.\nThis is a special introductory class to give participants an overview of what we're all about. You'll be introduced to the fundamentals of LudoSport Sporting Light Saber Combat: basic stances, movement, offensive and defensive techniques.\nYou'll also get a chance to spar at the end of every class (time permitting)!\nPrice: FREE!\xa0 \nHOWEVER...since we have a limited number of sabers available for use, in order to guarantee that we have enough sabers for everyone, we ask that you put down a deposit by purchasing a $5 ticket — we'll refund it when you arrive.\nPlease Bring:\nComfortable sportswear and footwear.\xa0\nThe Italian Designed Sport Saber LamaDiLuce\xa0Polaris SSe-1 will be available for your use for the duration of the class.\nCheck-in 15 minutes in advance.\n\nQ&A:\nWhere can I contact the organizer with any questions?\nPlease contact sanfrancisco@ludosport.net.\nDo I have to bring my printed ticket to the event?\nIf you paid a deposit for a saber, bring either your printed ticket, or e-ticket on Eventbrite app/email\nThe name on the registration/ticket doesn't match the attendee. Is that okay?\nWe encourage purchasing tickets for friends!\xa0 We'll refund the deposit-ticket they present for this event, so funds will be returned via whatever method was used to pay.\nIs there a minimum age requirement?\nSession is meant for participants of age 16+",
#     'html': '<H2>Learn to Wield a Light Saber!</H2>\n<P>At LudoSport, we teach students how to do actual improvisational sparring with light sabers (no choreography here!). With practice, students are able to safely duel with one another, and even eventually compete in official LudoSport tournaments.</P>\n<P>This is a special introductory class to give participants an overview of what we\'re all about. You\'ll be introduced to the fundamentals of LudoSport Sporting Light Saber Combat: basic stances, movement, offensive and defensive techniques.</P>\n<P>You\'ll also get a chance to spar at the end of every class (time permitting)!</P>\n<P><STRONG>Price: FREE!\xa0 </STRONG></P>\n<P><STRONG>HOWEVER...</STRONG>since we have a limited number of sabers available for use, in order to guarantee that we have enough sabers for everyone, we ask that you put down a deposit by purchasing a $5 ticket — we\'ll refund it when you arrive.</P>\n<H2>Please Bring:</H2>\n<H3 CLASS="MsoNormal">Comfortable sportswear and footwear.\xa0<BR></H3>\n<P CLASS="MsoNormal">The Italian Designed Sport Saber <A HREF="http://www.lamadiluce.it/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">LamaDiLuce</A>\xa0Polaris SSe-1 will be available for your use for the duration of the class.<BR></P>\n<H3 CLASS="MsoNormal">Check-in 15 minutes in advance.</H3>\n<P><SPAN CLASS="_5yl5"></SPAN><BR></P>\n<H2>Q&A:</H2>\n<H3 CLASS="MsoNormal">Where can I contact the organizer with any questions?</H3>\n<P>Please contact sanfrancisco@ludosport.net.</P>\n<H3>Do I have to bring my printed ticket to the event?</H3>\n<P>If you paid a deposit for a saber, bring either your printed ticket, or e-ticket on Eventbrite app/email</P>\n<H3>The name on the registration/ticket doesn\'t match the attendee. Is that okay?</H3>\n<P>We encourage purchasing tickets for friends!\xa0 We\'ll refund the deposit-ticket they present for this event, so funds will be returned via whatever method was used to pay.<BR></P>\n<H3>Is there a minimum age requirement?</H3>\n<P>Session is meant for participants of age 16+</P>'},
#    'id': '49519460038',
#    'url': 'https://www.eventbrite.com/e/free-outdoor-class-intro-to-light-saber-combat-tickets-49519460038?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-10T19:00:00',
#     'utc': '2018-10-11T02:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-10T21:00:00',
#     'utc': '2018-10-11T04:00:00Z'},
#    'organization_id': '204799884757',
#    'created': '2018-08-25T22:01:01Z',
#    'changed': '2018-10-01T13:47:29Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': True,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': False,
#    'version': '3.0.0',
#    'logo_id': '48894543',
#    'organizer_id': '13088328429',
#    'venue_id': '26409043',
#    'category_id': '108',
#    'subcategory_id': None,
#    'format_id': '9',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/49519460038/',
#    'is_externally_ticketed': False,
#    'series_id': '49519394843',
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 564},
#      'width': 4032,
#      'height': 2016},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48894543%2F204799884757%2F1%2Foriginal.jpg?auto=compress&s=e4c3fb966cfd46b85942e8aae7858a8e',
#      'width': 4032,
#      'height': 3024},
#     'id': '48894543',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48894543%2F204799884757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C564%2C4032%2C2016&s=8ea2c4c564630496241d1164994f68dc',
#     'aspect_ratio': '2',
#     'edge_color': '#1c1915',
#     'edge_color_set': True}},
#   {'name': {'text': 'San Francisco, CA - Free Redfin Home Buying Webinar',
#     'html': 'San Francisco, CA - Free Redfin Home Buying Webinar'},
#    'description': {'text': "Home Buying Webinar\n\n Thinking about buying a home but don't know where to start?\n\t\tRedfin Agent Chris Jurach\nwill walk you through the home-buying process from the convenience of your computer so you know what to expect.\n\n\n\n\t\tVideo: https://bit.ly/2Nl0VrE \n\n\n\n    What we'll cover:\n    \n\t\tIs buying for you?\n\t\tSan Francisco home prices, inventory & market conditions\n\t\tPurchasing a new home remotely\n\t\tHome financing & the purchase process\n    \n\n\n\t\n\t\t\n\t\t\tHosted by Redfin Agent: \n\t\t\tChris Jurach \n\t\t\n\t\n\n    \n    Free and Never any Obligation\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn't obligate you to work with a Redfin Agent but it does mean\n    you agree to Redfin Terms of Use,\n    Privacy Policy, and\n    End User License Agreement.\n    We will also create a Redfin account for you.\n\n\n\tCan't make it? Click here for a full list of free Redfin classes and events!\n\n",
#     'html': '<H2>Home Buying Webinar</H2>\n\n<P> Thinking about buying a home but don\'t know where to start?\n\t\tRedfin Agent Chris Jurach\nwill walk you through the home-buying process from the convenience of your computer so you know what to expect.\n</P>\n\n<P>\n\t\tVideo: https://bit.ly/2Nl0VrE <BR>\n</P>\n\n<P>\n    <SPAN><STRONG>What we\'ll cover:</STRONG></SPAN>\n    </P><UL>\n\t\t<LI>Is buying for you?</LI>\n\t\t<LI>San Francisco home prices, inventory &amp; market conditions</LI>\n\t\t<LI>Purchasing a new home remotely</LI>\n\t\t<LI>Home financing &amp; the purchase process</LI>\n    </UL>\n<P></P>\n\n\t<DIV>\n\t\t<P>\n\t\t\t<SPAN><STRONG>Hosted by Redfin Agent:</STRONG></SPAN> <BR>\n\t\t\t<A HREF="https://www.redfin.com/real-estate-agents/chris-jurach" REL="nofollow">Chris Jurach</A> <BR>\n\t\t</P>\n\t</DIV>\n<P>\n    <BR>\n    </P><DIV><STRONG>Free and Never any Obligation</STRONG></DIV>\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn\'t obligate you to work with a Redfin Agent but it does mean\n    you agree to <A HREF="https://www.redfin.com/about/terms-of-use" REL="nofollow">Redfin Terms of Use</A>,\n    <A HREF="https://www.redfin.com/about/privacy-policy" REL="nofollow">Privacy Policy</A>, and\n    <A HREF="https://www.redfin.com/about/terms-of-use#eula" REL="nofollow">End User License Agreement</A>.\n    We will also create a Redfin account for you.\n<P></P>\n<P>\n\t<A HREF="https://www.redfin.com/buy-a-home/classes-and-events" REL="nofollow">Can\'t make it? Click here for a full list of free Redfin classes and events!</A>\n</P>\n'},
#    'id': '50982603339',
#    'url': 'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-home-buying-webinar-tickets-50982603339?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-03T11:00:00',
#     'utc': '2018-11-03T18:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-03T12:00:00',
#     'utc': '2018-11-03T19:00:00Z'},
#    'organization_id': '19089675839',
#    'created': '2018-10-03T21:32:06Z',
#    'changed': '2018-10-03T21:33:47Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': None,
#    'hide_end_date': None,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'api',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '32391916',
#    'organizer_id': '1399261745',
#    'venue_id': '27157935',
#    'category_id': None,
#    'subcategory_id': None,
#    'format_id': None,
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50982603339/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0},
#      'width': 1280,
#      'height': 640},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391916%2F179505884546%2F1%2Foriginal.jpg?auto=compress&s=6c061b35bffba3a6fa87d8511cdf2a94',
#      'width': 1280,
#      'height': 640},
#     'id': '32391916',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391916%2F179505884546%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C1280%2C640&s=033f7b2a8f21d5489121ada525b10fb6',
#     'aspect_ratio': '2',
#     'edge_color': '#c2aeaf',
#     'edge_color_set': True}},
#   {'name': {'text': 'San Francisco, CA - Free Redfin Preparing to Sell in the New Year Class',
#     'html': 'San Francisco, CA - Free Redfin Preparing to Sell in the New Year Class'},
#    'description': {'text': "Preparing to Sell in the New Year Class\nThinking about selling?\n\t\tJoin Redfin Agent, Benjamin Faber,\n and 8-10 homeowners like you to discuss selling your home in today's real estate market. \n We'll go over the information you want to know over dinner and drinks, so bring your questions!\n\n\n\n\tWhat we'll cover:\n\t\n\t\tBest time to sell\n\t\tWhat's your house worth?\n\t\t5 things that will help sell your home faster, for more money\n\t\tSan Francisco area home prices, inventory & market conditions\n\t\n\tFree bites & beverages will be provided!\n\t\n\n\t\n\t\t\n\t\t\tHosted by Redfin Agent: \n\t\t\tBenjamin Faber \n\t\t\n\t\n\n    \n    Free and Never any Obligation\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn't obligate you to work with a Redfin Agent but it does mean\n    you agree to Redfin Terms of Use,\n    Privacy Policy, and\n    End User License Agreement.\n    We will also create a Redfin account for you.\n\n\n\tCan't make it? Click here for a full list of free Redfin classes and events!\n\n",
#     'html': '<H2>Preparing to Sell in the New Year Class</H2>\n<P><SPAN><STRONG>Thinking about selling?</STRONG></SPAN><BR>\n\t\tJoin Redfin Agent, Benjamin Faber,\n and 8-10 homeowners like you to discuss selling your home in today\'s real estate market. \n We\'ll go over the information you want to know over dinner and drinks, so bring your questions!\n</P>\n\n<P>\n\t<SPAN><STRONG>What we\'ll cover:</STRONG></SPAN>\n\t</P><UL>\n\t\t<LI>Best time to sell</LI>\n\t\t<LI>What\'s your house worth?</LI>\n\t\t<LI>5 things that will help sell your home faster, for more money</LI>\n\t\t<LI>San Francisco area home prices, inventory &amp; market conditions</LI>\n\t</UL>\n\t<P><SPAN><STRONG>Free bites &amp; beverages will be provided!</STRONG></SPAN></P>\n\t<BR>\n<P></P>\n\t<DIV>\n\t\t<P>\n\t\t\t<SPAN><STRONG>Hosted by Redfin Agent:</STRONG></SPAN> <BR>\n\t\t\t<A HREF="https://www.redfin.com/real-estate-agents/benjamin-faber" REL="nofollow">Benjamin Faber</A> <BR>\n\t\t</P>\n\t</DIV>\n<P>\n    <BR>\n    </P><DIV><STRONG>Free and Never any Obligation</STRONG></DIV>\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn\'t obligate you to work with a Redfin Agent but it does mean\n    you agree to <A HREF="https://www.redfin.com/about/terms-of-use" REL="nofollow">Redfin Terms of Use</A>,\n    <A HREF="https://www.redfin.com/about/privacy-policy" REL="nofollow">Privacy Policy</A>, and\n    <A HREF="https://www.redfin.com/about/terms-of-use#eula" REL="nofollow">End User License Agreement</A>.\n    We will also create a Redfin account for you.\n<P></P>\n<P>\n\t<A HREF="https://www.redfin.com/buy-a-home/classes-and-events" REL="nofollow">Can\'t make it? Click here for a full list of free Redfin classes and events!</A>\n</P>\n'},
#    'id': '50981560219',
#    'url': 'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-preparing-to-sell-in-the-new-year-class-tickets-50981560219?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-30T18:30:00',
#     'utc': '2018-10-31T01:30:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-30T20:30:00',
#     'utc': '2018-10-31T03:30:00Z'},
#    'organization_id': '19089675839',
#    'created': '2018-10-03T21:02:07Z',
#    'changed': '2018-10-03T21:07:00Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': None,
#    'hide_end_date': None,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'api',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '32391836',
#    'organizer_id': '1399261745',
#    'venue_id': '27157255',
#    'category_id': None,
#    'subcategory_id': None,
#    'format_id': None,
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50981560219/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0},
#      'width': 1280,
#      'height': 640},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391836%2F179505884546%2F1%2Foriginal.jpg?auto=compress&s=c35110f0cee288a4dc0e4d34d77c204b',
#      'width': 1280,
#      'height': 640},
#     'id': '32391836',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391836%2F179505884546%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C1280%2C640&s=07ef4048d3456f30cfda92ec8fd1cad8',
#     'aspect_ratio': '2',
#     'edge_color': '#6e584f',
#     'edge_color_set': True}},
#   {'name': {'text': 'San Francisco, CA - Free Redfin Preparing to Sell in the New Year Class',
#     'html': 'San Francisco, CA - Free Redfin Preparing to Sell in the New Year Class'},
#    'description': {'text': "Preparing to Sell in the New Year\nThinking about selling?\n\t\tJoin Redfin Agent, Benjamin Faber,\n and 8-10 homeowners like you to discuss selling your home in today's real estate market. \n We'll go over the information you want to know over dinner and drinks, so bring your questions!\n\n\n\n\tWhat we'll cover:\n\t\n\t\tBest time to sell\n\t\tWhat's your house worth?\n\t\t5 things that will help sell your home faster, for more money\n\t\tSan Francisco area home prices, inventory & market conditions\n\t\n\tFree bites & beverages will be provided!\n\t\n\n\t\n\t\t\n\t\t\tHosted by Redfin Agent: \n\t\t\tBenjamin Faber \n\t\t\n\t\n\n    \n    Free and Never any Obligation\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn't obligate you to work with a Redfin Agent but it does mean\n    you agree to Redfin Terms of Use,\n    Privacy Policy, and\n    End User License Agreement.\n    We will also create a Redfin account for you.\n\n\n\tCan't make it? Click here for a full list of free Redfin classes and events!\n\n",
#     'html': '<H2>Preparing to Sell in the New Year</H2>\n<P><SPAN><STRONG>Thinking about selling?</STRONG></SPAN><BR>\n\t\tJoin Redfin Agent, Benjamin Faber,\n and 8-10 homeowners like you to discuss selling your home in today\'s real estate market. \n We\'ll go over the information you want to know over dinner and drinks, so bring your questions!\n</P>\n\n<P>\n\t<SPAN><STRONG>What we\'ll cover:</STRONG></SPAN>\n\t</P><UL>\n\t\t<LI>Best time to sell</LI>\n\t\t<LI>What\'s your house worth?</LI>\n\t\t<LI>5 things that will help sell your home faster, for more money</LI>\n\t\t<LI>San Francisco area home prices, inventory &amp; market conditions</LI>\n\t</UL>\n\t<P><SPAN><STRONG>Free bites &amp; beverages will be provided!</STRONG></SPAN></P>\n\t<BR>\n<P></P>\n\t<DIV>\n\t\t<P>\n\t\t\t<SPAN><STRONG>Hosted by Redfin Agent:</STRONG></SPAN> <BR>\n\t\t\t<A HREF="https://www.redfin.com/real-estate-agents/benjamin-faber" REL="nofollow">Benjamin Faber</A> <BR>\n\t\t</P>\n\t</DIV>\n<P>\n    <BR>\n    </P><DIV><STRONG>Free and Never any Obligation</STRONG></DIV>\n    Our mission is to reinvent real estate. A big part of this means we want you to be as informed as possible about\n    buying or selling a home. Attending this class doesn\'t obligate you to work with a Redfin Agent but it does mean\n    you agree to <A HREF="https://www.redfin.com/about/terms-of-use" REL="nofollow">Redfin Terms of Use</A>,\n    <A HREF="https://www.redfin.com/about/privacy-policy" REL="nofollow">Privacy Policy</A>, and\n    <A HREF="https://www.redfin.com/about/terms-of-use#eula" REL="nofollow">End User License Agreement</A>.\n    We will also create a Redfin account for you.\n<P></P>\n<P>\n\t<A HREF="https://www.redfin.com/buy-a-home/classes-and-events" REL="nofollow">Can\'t make it? Click here for a full list of free Redfin classes and events!</A>\n</P>\n'},
#    'id': '50982327514',
#    'url': 'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-preparing-to-sell-in-the-new-year-class-tickets-50982327514?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-12-12T18:30:00',
#     'utc': '2018-12-13T02:30:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-12-12T20:30:00',
#     'utc': '2018-12-13T04:30:00Z'},
#    'organization_id': '19089675839',
#    'created': '2018-10-03T21:24:19Z',
#    'changed': '2018-10-03T21:25:12Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': None,
#    'hide_end_date': None,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'api',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '32391836',
#    'organizer_id': '1399261745',
#    'venue_id': '27157775',
#    'category_id': None,
#    'subcategory_id': None,
#    'format_id': None,
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50982327514/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0},
#      'width': 1280,
#      'height': 640},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391836%2F179505884546%2F1%2Foriginal.jpg?auto=compress&s=c35110f0cee288a4dc0e4d34d77c204b',
#      'width': 1280,
#      'height': 640},
#     'id': '32391836',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F32391836%2F179505884546%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C1280%2C640&s=07ef4048d3456f30cfda92ec8fd1cad8',
#     'aspect_ratio': '2',
#     'edge_color': '#6e584f',
#     'edge_color_set': True}},
#   {'name': {'text': 'SALSA DANCING and FREE CLASS & PARTY on Sundays in SF (iHeartMambo) MUST ARRIVE EARLY AND TAKE BEGINNER CLASS.',
#     'html': 'SALSA DANCING and FREE CLASS &amp; PARTY on Sundays in SF (iHeartMambo) MUST ARRIVE EARLY AND TAKE BEGINNER CLASS.'},
# ...
#    'version': '3.0.0',
#    'logo_id': '50378782',
#    'organizer_id': '6170715747',
#    'venue_id': '27001546',
#    'category_id': '111',
#    'subcategory_id': '11002',
#    'format_id': '3',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/50677276097/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 1012},
#      'width': 2550,
#      'height': 1275},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50378782%2F4395600315%2F1%2Foriginal.jpg?auto=compress&s=ee7fdf7dcf1b95c7c396c676a2ba509b',
#      'width': 2550,
#      'height': 3300},
#     'id': '50378782',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50378782%2F4395600315%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C1012%2C2550%2C1275&s=cb8bed6ee130c2ce49c5a3c0f69a8817',
#     'aspect_ratio': '2',
#     'edge_color': '#021a26',
#     'edge_color_set': True}},
#   {'name': {'text': 'Jackpot! An Evening of Music, Food, Dancing & Game Show Entertainment',
#     'html': 'Jackpot! An Evening of Music, Food, Dancing &amp; Game Show Entertainment'},
#    'description': {'text': 'CCA Wattis Institute presentsJackpot! An Evening of Art, Music, Cake, Food Trucks, Dancing & Game Show Entertainment Celebrating the\xa020th Anniversary of The WattisFriday, Nov. 2, 2018Wattis Institute for Contemporary Arts350 Kansas St in SF7pm\nThe Wattis Institute is turning 20 years old this year! To celebrate this significant milestone, we are hosting a special evening of music, cake, dancing, and game show entertainment. On the night of November 2nd the Wattis will be transformed into a game show set, with games based on all of your old favourites: Price is Right, Jeopardy, Family Feud, and other classics!\nFree and open to all.\n\nAbout California College of the Arts\nLocated at the center of innovation and technology in the San Francisco Bay Area, California College of the Arts is home to a world-renowned faculty of practicing artists and entrepreneurs, and a diverse community of makers that are boldly reimagining the world. Offering 22 undergraduate and 11 graduate programs in fine arts, architecture, design, and writing, CCA’s creative culture is built around the ideals of interdisciplinary collaboration, sustainability, and community engagement.\n\n',
#     'html': '<H2 CLASS="gmail_default"><SPAN>CCA Wattis Institute presents<BR>Jackpot! An Evening of Art, Music, Cake, Food Trucks, Dancing &amp; Game Show Entertainment Celebrating the\xa020th Anniversary of The Wattis<BR>Friday, Nov. 2, 2018</SPAN><BR>Wattis Institute for Contemporary Arts<BR>350 Kansas St in SF<BR>7pm<BR><BR></H2>\n<P><SPAN><SPAN>The <SPAN CLASS="il">Wattis</SPAN> Institute is turning 20 years old this year! To celebrate this significant milestone, we are hosting a special evening of music, cake, dancing, and game show entertainment. On the night of November 2nd the <SPAN CLASS="il">Wattis</SPAN> will be transformed into a game show set, with games based on all of your old favourites: Price is Right, Jeopardy, Family Feud, and other classics!</SPAN></SPAN></P>\n<P><EM><STRONG>Free and open to all.</STRONG></EM></P>\n<P><BR></P>\n<H3>About California College of the Arts</H3>\n<P><SPAN>Located at the center of innovation and technology in the San Francisco Bay Area, <A HREF="https://www.cca.edu/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">California College of the Arts</A> is home to a world-renowned faculty of practicing artists and entrepreneurs, and a diverse community of makers that are boldly reimagining the world. Offering 22 undergraduate and 11 graduate programs in fine arts, architecture, design, and writing, CCA’s creative culture is built around the ideals of interdisciplinary collaboration, sustainability, and community engagement.</SPAN></P>\n<P><BR></P>\n<P><BR></P>'},
#    'id': '51049312869',
#    'url': 'https://www.eventbrite.com/e/jackpot-an-evening-of-music-food-dancing-game-show-entertainment-tickets-51049312869?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-02T19:00:00',
#     'utc': '2018-11-03T02:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-02T23:00:00',
#     'utc': '2018-11-03T06:00:00Z'},
#    'organization_id': '94582111473',
#    'created': '2018-10-05T00:02:04Z',
#    'changed': '2018-10-05T17:09:58Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 1800,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': True,
#    'version': '3.0.0',
#    'logo_id': '50881846',
#    'organizer_id': '6281618671',
#    'venue_id': '27186488',
#    'category_id': '105',
#    'subcategory_id': '5008',
#    'format_id': '11',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/51049312869/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 68},
#      'width': 2000,
#      'height': 1000},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50881846%2F94582111473%2F1%2Foriginal.jpg?auto=compress&s=3d977308adfbd08ca34d2ede8d031ae8',
#      'width': 2000,
#      'height': 3067},
#     'id': '50881846',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50881846%2F94582111473%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C68%2C2000%2C1000&s=55e89ead6b0a1d6c98f75817e42b7cd3',
#     'aspect_ratio': '2',
#     'edge_color': '#0a124e',
#     'edge_color_set': True}},
#   {'name': {'text': 'THE FALL BALL', 'html': 'THE FALL BALL'},
#    'description': {'text': 'San Francisco’s most exciting singles event of the Fall Season is in the lovely Golden Gate Ballroom of the Marriott Fisherman’s Wharf! $15/advance (by Oct 12) or $20 cash at the door includes dancing to your favorite hits. Dressy attire requested. Adults of all ages welcome. Saturday October 13, 2018, 8pm-12.\nLOCATION: Marriott Hotel Fisherman’s Wharf, Golden Gate Ballroom, 1250 Columbus Avenue at Bay Street, San Francisco CA 94133. Some free street parking. Lowest priced paid parking is at Anchorage Square Parking Lot, 500 Beach Street.\nCO-SPONSORED by\xa0The Society of Single Professionals, the world’s largest non-profit singles organization; Singles Supper Club,\xa0San Francisco Singles,\xa0Bay Area Single Boomers,\xa0Single Professionals Internet Network (SPiN);\xa0Cougar Parties,\xa040+ Singles,\xa0Single n’ Professional,\xa0Lifestyle Parties,\xa0Get a Love Life!\xa0and many others.',
#     'html': '<P>San Francisco’s most exciting singles event of the Fall Season is in the lovely Golden Gate Ballroom of the Marriott Fisherman’s Wharf! $15/advance (by Oct 12) or $20 cash at the door includes dancing to your favorite hits. Dressy attire requested. Adults of all ages welcome. Saturday October 13, 2018, 8pm-12.</P>\n<P>LOCATION: Marriott Hotel Fisherman’s Wharf, Golden Gate Ballroom, 1250 Columbus Avenue at Bay Street, San Francisco CA 94133. Some free street parking. Lowest priced paid parking is at Anchorage Square Parking Lot, 500 Beach Street.</P>\n<P>CO-SPONSORED by\xa0<EM>The Society of Single Professionals</EM>, the world’s largest non-profit singles organization; Singles Supper Club,\xa0<EM><A HREF="https://www.meetup.com/SFSingles/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">San Francisco Singles</A>,\xa0<A HREF="https://www.meetup.com/Bay-area-single-boomers-Social-Meetup/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">Bay Area Single Boomers</A></EM>,\xa0<EM><A HREF="https://www.meetup.com/singleprofessionals/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">Single Professionals Internet Network (SPiN</A>);\xa0<A HREF="https://www.meetup.com/Cougar-Parties-Cruises/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">Cougar Parties</A>,\xa0<A HREF="https://www.meetup.com/Singles-Over-40-and-Fun/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">40+ Singles</A>,\xa0<A HREF="https://www.meetup.com/singlenprofessionals/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">Single n’ Professional</A>,\xa0<A HREF="https://www.meetup.com/Lifestyle-Parties-Hiking-Meetups/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">Lifestyle Parties</A>,\xa0<SPAN><A HREF="http://www.getalovelife.net/" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow"><SPAN><SPAN>Get a Love Life!</SPAN></SPAN></A></SPAN></EM>\xa0and many others.</P>'},
#    'id': '51111284227',
#    'url': 'https://www.eventbrite.com/e/the-fall-ball-tickets-51111284227?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-13T20:00:00',
#     'utc': '2018-10-14T03:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-10-14T00:00:00',
#     'utc': '2018-10-14T07:00:00Z'},
#    'organization_id': '12663738963',
#    'created': '2018-10-07T00:59:30Z',
#    'changed': '2018-10-07T17:54:51Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': False,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': False,
#    'version': '3.0.0',
#    'logo_id': '50924415',
#    'organizer_id': '11999337482',
#    'venue_id': '18882461',
#    'category_id': None,
#    'subcategory_id': None,
#    'format_id': '11',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/51111284227/',
#    'is_externally_ticketed': False,
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 69},
#      'width': 600,
#      'height': 300},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50924415%2F12663738963%2F1%2Foriginal.jpg?auto=compress&s=26c2527478493ad7605b63e8f230594d',
#      'width': 600,
#      'height': 449},
#     'id': '50924415',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50924415%2F12663738963%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C69%2C600%2C300&s=f3d60afdb0880a911ef6a98f828464a9',
#     'aspect_ratio': '2',
#     'edge_color': '#ffffff',
#     'edge_color_set': True}},
#   {'name': {'text': 'The Female Bawdy Show', 'html': 'The Female Bawdy Show'},
#    'description': {'text': 'The ladies of Chardonnay get humorously indecent in this brand new big, buttery, full-bawdied sketch comedy show. "The Female Bawdy Show" is a raucous romp through modern tales of ribaldry playing for 4 nights only. Loin tingling highlights include adult women pony lovers, British S.T.D’s, drop crotch pants, and an Instant Pot. We go there. Come both ladies and gents and let out your inner bawdy beast with San Francisco’s longest running all-female sketch group this November!\nPlaying November 9, 10, 16, 17 at 8pm.Show is about 1 hour with no intermission.\n\n\nPianoFight’s not just a theater, it’s also a restaurant and bar!\n★★★★½ on Yelp★★★★½ on Google★★★★★ on Facebook\n“Reasonably priced New American bites and cocktails in an unpretentious setting” - Zagat\n“The best party spot in the neighborhood” - The Bay Bridged\n“A hot SF scene” - SF Chronicle\nIf you plan on dining, we recommend you arrive 1.5 hours early so you have plenty of time to eat before the show. Restaurant seating is first come first serve. Drinks are always allowed in the theaters.\nPARKINGStreet parking is free after 6pm. We’re located 2 blocks from Powell BART, numerous muni lines and there are 3 parking lots within 1 block.',
#     'html': '<P>The ladies of Chardonnay get humorously indecent in this brand new big, buttery, full-bawdied sketch comedy show. "The Female Bawdy Show" is a raucous romp through modern tales of ribaldry playing for 4 nights only. <BR>Loin tingling highlights include adult women pony lovers, British S.T.D’s, drop crotch pants, and an Instant Pot. We go there. Come both ladies and gents and let out your inner bawdy beast with San Francisco’s longest running all-female sketch group this November!</P>\n<P>Playing November 9, 10, 16, 17 at 8pm.<BR>Show is about 1 hour with no intermission.</P>\n<P><BR></P>\n<HR>\n<H2>PianoFight’s not just a theater, it’s also a restaurant and bar!</H2>\n<P>★★★★½ on Yelp<BR>★★★★½ on Google<BR>★★★★★ on Facebook</P>\n<P><EM>“Reasonably priced New American bites and cocktails in an unpretentious setting” - Zagat</EM></P>\n<P><EM>“The best party spot in the neighborhood” - The Bay Bridged</EM></P>\n<P><EM>“A hot SF scene” - SF Chronicle</EM></P>\n<P>If you plan on <A HREF="https://www.pianofight.com/menu" TARGET="_blank" REL="noreferrer noopener nofollow noopener noreferrer nofollow">dining</A>, we recommend you arrive 1.5 hours early so you have plenty of time to eat before the show. Restaurant seating is first come first serve. Drinks are always allowed in the theaters.</P>\n<P>PARKING<BR>Street parking is free after 6pm. We’re located 2 blocks from Powell BART, numerous muni lines and there are 3 parking lots within 1 block.</P>'},
#    'id': '51122804685',
#    'url': 'https://www.eventbrite.com/e/the-female-bawdy-show-tickets-51122804685?aff=ebapi',
#    'start': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-09T20:00:00',
#     'utc': '2018-11-10T04:00:00Z'},
#    'end': {'timezone': 'America/Los_Angeles',
#     'local': '2018-11-09T21:30:00',
#     'utc': '2018-11-10T05:30:00Z'},
#    'organization_id': '115446603665',
#    'created': '2018-10-07T21:12:37Z',
#    'changed': '2018-10-07T21:12:44Z',
#    'capacity': None,
#    'capacity_is_custom': None,
#    'status': 'live',
#    'currency': 'USD',
#    'listed': True,
#    'shareable': True,
#    'online_event': False,
#    'tx_time_limit': 480,
#    'hide_start_date': False,
#    'hide_end_date': False,
#    'locale': 'en_US',
#    'is_locked': False,
#    'privacy_setting': 'unlocked',
#    'is_series': True,
#    'is_series_parent': False,
#    'is_reserved_seating': False,
#    'show_pick_a_seat': False,
#    'show_seatmap_thumbnail': False,
#    'show_colors_in_seatmap_thumbnail': False,
#    'source': 'create_2.0',
#    'is_free': False,
#    'version': '3.0.0',
#    'logo_id': '50940555',
#    'organizer_id': '7317491375',
#    'venue_id': '13596593',
#    'category_id': '105',
#    'subcategory_id': '5010',
#    'format_id': '6',
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/51122804685/',
#    'is_externally_ticketed': False,
#    'series_id': '51122507797',
#    'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 0},
#      'width': 800,
#      'height': 400},
#     'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50940555%2F144154840397%2F1%2Foriginal.jpg?auto=compress&s=2493fecbc0f3c730a359338f56f51d4b',
#      'width': 800,
#      'height': 400},
#     'id': '50940555',
#     'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50940555%2F144154840397%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C800%2C400&s=bf5bb37dce0ca27ca6dbc9b9139f3ce8',
#     'aspect_ratio': '2',
#     'edge_color': '#38b2b7',
#     'edge_color_set': True}}],
#  'location': {'latitude': '37.774930',
#   'augmented_location': {'city': 'San Francisco',
#    'region': 'California',
#    'country': 'United States'},
#   'within': '9.91082317248',
#   'longitude': '-122.419416',
#   'address': 'san francisco'}}

# %%
# Create a variable "response" 
    # Set it to the response of the api call converted from json format.
response = requests.get(q_url).json()

# Use pprint to see the beautiful response.
pp.pprint(response)
# Out:
# {'events': [{'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '101',
#              'changed': '2018-09-28T00:20:47Z',
#              'created': '2018-09-22T05:01:02Z',
#              'currency': 'USD',
#              'description': {'html': '<P><SPAN>Join us for a crash course on '
#                                      'SaaS Pricing and Packaging. We’ll be '
#                                      'going through the fundamentals of '
#                                      'product packaging, the pros, and cons of '
#                                      'different pricing models, and diagnose '
#                                      'real-world examples. Understand how to '
#                                      'take methodology and put it to practice '
#                                      'with your Sales '
#                                      'team.</SPAN><BR><BR><SPAN>We’ll cover '
#                                      'topics such as:</SPAN><BR><BR><SPAN>· '
#                                      'Creating the right value levers and '
#                                      'packaging to maximize '
#                                      'revenue</SPAN><BR><BR><SPAN>· Partnering '
#                                      'with Sales on deal strategy and value '
#                                      'selling</SPAN><BR><BR><SPAN>· Evaluating '
#                                      'and measuring the health of your current '
#                                      'pricing '
#                                      'model</SPAN><BR><SPAN></SPAN></P>\n'
#                                      '<P><STRONG>About the instructor:\xa0'
#                                      '</STRONG></P>\n'
#                                      '<P>Johnny Cheng:\xa0<A CLASS="link" '
#                                      'HREF="https://www.linkedin.com/in/jdcheng/" '
#                                      'TARGET="__blank" '
#                                      'TITLE="https://www.linkedin.com/in/jdcheng/" '
#                                      'REL="nofollow">https://www.linkedin.com/in/jdcheng/</A></P>\n'
#                                      '<P><SPAN>Johnny Cheng is the Director of '
#                                      'Product Marketing, Pricing and Packaging '
#                                      'at Gainsight. He has 10+ years of '
#                                      'Product Marketing and Business Analyst '
#                                      'experience in the tech industry. His '
#                                      'specialization is SaaS Pricing, which '
#                                      'he’s lead at several companies including '
#                                      'Marketo. He’s a self-proclaimed Mathlete '
#                                      'and loves to create Excel charts in his '
#                                      'free time.</SPAN></P>\n'
#                                      '<P><SPAN><IMG '
#                                      'SRC="https://cdn.evbuc.com/eventlogos/152288202/headshot-1.jpg"></SPAN></P>',
#                              'text': 'Join us for a crash course on SaaS '
#                                      'Pricing and Packaging. We’ll be going '
#                                      'through the fundamentals of product '
#                                      'packaging, the pros, and cons of '
#                                      'different pricing models, and diagnose '
#                                      'real-world examples. Understand how to '
#                                      'take methodology and put it to practice '
#                                      'with your Sales team.We’ll cover topics '
#                                      'such as:· Creating the right value '
#                                      'levers and packaging to maximize '
#                                      'revenue· Partnering with Sales on deal '
#                                      'strategy and value selling· Evaluating '
#                                      'and measuring the health of your current '
#                                      'pricing model\n'
#                                      'About the instructor:\xa0\n'
#                                      'Johnny Cheng:\xa0'
#                                      'https://www.linkedin.com/in/jdcheng/\n'
#                                      'Johnny Cheng is the Director of Product '
#                                      'Marketing, Pricing and Packaging at '
#                                      'Gainsight. He has 10+ years of Product '
#                                      'Marketing and Business Analyst '
#                                      'experience in the tech industry. His '
#                                      'specialization is SaaS Pricing, which '
#                                      'he’s lead at several companies including '
#                                      'Marketo. He’s a self-proclaimed Mathlete '
#                                      'and loves to create Excel charts in his '
#                                      'free time.\n'},
#              'end': {'local': '2018-10-15T22:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-10-16T05:00:00Z'},
#              'format_id': '9',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '50554218027',
#              'is_externally_ticketed': False,
#              'is_free': False,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 433,
#                                     'top_left': {'x': 0, 'y': 20},
#                                     'width': 866},
#                       'edge_color': None,
#                       'edge_color_set': True,
#                       'id': '50202705',
#                       'original': {'height': 475,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50202705%2F153354219414%2F1%2Foriginal.jpg?auto=compress&s=081556d2644deca640fed2844552d7b4',
#                                    'width': 867},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50202705%2F153354219414%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C20%2C866%2C433&s=b2a4b42b001ed38418ee08585a4a5c8c'},
#              'logo_id': '50202705',
#              'name': {'html': 'Product Marketing Workshop: Building a SaaS '
#                               'Pricing and Packaging Foundation for Growth',
#                       'text': 'Product Marketing Workshop: Building a SaaS '
#                               'Pricing and Packaging Foundation for Growth'},
#              'online_event': False,
#              'organization_id': '153354219414',
#              'organizer_id': '17485975975',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/50554218027/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-10-15T19:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-10-16T02:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '1007',
#              'tx_time_limit': 600,
#              'url': 'https://www.eventbrite.com/e/product-marketing-workshop-building-a-saas-pricing-and-packaging-foundation-for-growth-tickets-50554218027?aff=ebapi',
#              'venue_id': '26940299',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '107',
#              'changed': '2018-09-25T18:43:53Z',
#              'created': '2018-09-25T18:43:03Z',
#              'currency': 'USD',
#              'description': {'html': '<H2><STRONG>FREE CPR Class by Sports '
#                                      'Basement</STRONG></H2>\n'
#                                      '<P CLASS="p1"><STRONG>Course '
#                                      'Name</STRONG>:\xa0STS '
#                                      'CPR<BR><STRONG>Description:</STRONG> CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, '
#                                      'choke-saving<BR><STRONG>Length:</STRONG>\xa0'
#                                      '2 hours<BR><STRONG>Course '
#                                      'Price</STRONG>:\xa0'
#                                      '$0<BR><STRONG>Cancellation '
#                                      'Policy:</STRONG> Please let us know if '
#                                      'you want to cancel, so we can give your '
#                                      'spot to someone else.<BR></P>\n'
#                                      '<P '
#                                      'CLASS="p1"><STRONG>Certification</STRONG><BR>This '
#                                      'course is not by the American Heart '
#                                      'Association or the American Red Cross. '
#                                      'If you need to have an official '
#                                      'certification card for a work '
#                                      'requirement, you would need to take an '
#                                      'American Heart Association course. View '
#                                      'our <A HREF="http://www.bayareacpr.org" '
#                                      'TARGET="_blank" TITLE="Bay Area American '
#                                      'Heart Association" REL="noreferrer '
#                                      'noopener nofollow noopener noreferrer '
#                                      'nofollow">website</A> for courses and '
#                                      'prices.\xa0<SPAN '
#                                      'CLASS="Apple-converted-space">\xa0'
#                                      '</SPAN>This course is for those who do '
#                                      'not require an official certification '
#                                      'card.</P>\n'
#                                      '<P CLASS="p1"><STRONG>Who should\xa0'
#                                      '<SPAN CLASS="s1">NOT</SPAN>\xa0take this '
#                                      'CPR class</STRONG><BR>Medical or '
#                                      'healthcare professionals must take the '
#                                      'BLS class. Childcare providers who need '
#                                      'EMSA certification must take Pediatric '
#                                      'First-aid/CPR course.</P>\n'
#                                      '<P CLASS="p4"><STRONG>Free Keychain CPR '
#                                      'Breathing Mask ($10 '
#                                      'value)</STRONG><BR>On the day of your '
#                                      'class, you can check in with your mobile '
#                                      'phone on Facebook, Foursquare, or Yelp '
#                                      'and receive a free keychain CPR '
#                                      'mask.</P>\n'
#                                      '<P '
#                                      'CLASS="p4"><STRONG>Classroom</STRONG><BR>Children '
#                                      'are not allowed in the classroom. For '
#                                      'your convenience we offer free tea, '
#                                      'granola bars, and a phone charging '
#                                      'station.</P>\n'
#                                      '<P><STRONG>Questions?</STRONG><BR>Give '
#                                      'us a call at 415-437-1600</P>',
#                              'text': 'FREE CPR Class by Sports Basement\n'
#                                      'Course Name:\xa0STS CPRDescription: CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, choke-savingLength:\xa02 '
#                                      'hoursCourse Price:\xa0$0Cancellation '
#                                      'Policy: Please let us know if you want '
#                                      'to cancel, so we can give your spot to '
#                                      'someone else.\n'
#                                      'CertificationThis course is not by the '
#                                      'American Heart Association or the '
#                                      'American Red Cross. If you need to have '
#                                      'an official certification card for a '
#                                      'work requirement, you would need to take '
#                                      'an American Heart Association course. '
#                                      'View our website for courses and '
#                                      'prices.\xa0\xa0This course is for those '
#                                      'who do not require an official '
#                                      'certification card.\n'
#                                      'Who should\xa0NOT\xa0take this CPR '
#                                      'classMedical or healthcare professionals '
#                                      'must take the BLS class. Childcare '
#                                      'providers who need EMSA certification '
#                                      'must take Pediatric First-aid/CPR '
#                                      'course.\n'
#                                      'Free Keychain CPR Breathing Mask ($10 '
#                                      'value)On the day of your class, you can '
#                                      'check in with your mobile phone on '
#                                      'Facebook, Foursquare, or Yelp and '
#                                      'receive a free keychain CPR mask.\n'
#                                      'ClassroomChildren are not allowed in the '
#                                      'classroom. For your convenience we offer '
#                                      'free tea, granola bars, and a phone '
#                                      'charging station.\n'
#                                      'Questions?Give us a call at '
#                                      '415-437-1600'},
#              'end': {'local': '2019-01-15T11:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2019-01-15T19:00:00Z'},
#              'format_id': '9',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '50658880074',
#              'is_externally_ticketed': False,
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 1060,
#                                     'top_left': {'x': 0, 'y': 106},
#                                     'width': 2120},
#                       'edge_color': '#ddd7d2',
#                       'edge_color_set': True,
#                       'id': '50351711',
#                       'original': {'height': 1414,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351711%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=554e8b37e59fb4a91b18fc667b287fb5',
#                                    'width': 2121},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351711%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=01d9910b9d3546b4bd7ae5346a86bb78'},
#              'logo_id': '50351711',
#              'name': {'html': 'Sports Basement Free CPR Class in San Francisco',
#                       'text': 'Sports Basement Free CPR Class in San '
#                               'Francisco'},
#              'online_event': False,
#              'organization_id': '14268435757',
#              'organizer_id': '1086926597',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/50658880074/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2019-01-15T09:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2019-01-15T17:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '7003',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50658880074?aff=ebapi',
#              'venue_id': '974499',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '107',
#              'changed': '2018-09-25T20:24:13Z',
#              'created': '2018-09-25T18:17:10Z',
#              'currency': 'USD',
#              'description': {'html': '<H2><STRONG>FREE CPR Class by Sports '
#                                      'Basement</STRONG></H2>\n'
#                                      '<P CLASS="p1"><STRONG>Course '
#                                      'Name</STRONG>:\xa0STS '
#                                      'CPR<BR><STRONG>Description:</STRONG> CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, '
#                                      'choke-saving<BR><STRONG>Length:</STRONG>\xa0'
#                                      '2 hours<BR><STRONG>Course '
#                                      'Price</STRONG>:\xa0'
#                                      '$0<BR><STRONG>Cancellation '
#                                      'Policy:</STRONG> Please let us know if '
#                                      'you want to cancel, so we can give your '
#                                      'spot to someone else.<BR></P>\n'
#                                      '<P '
#                                      'CLASS="p1"><STRONG>Certification</STRONG><BR>This '
#                                      'course is not by the American Heart '
#                                      'Association or the American Red Cross. '
#                                      'If you need to have an official '
#                                      'certification card for a work '
#                                      'requirement, you would need to take an '
#                                      'American Heart Association course. View '
#                                      'our <A HREF="http://www.bayareacpr.org" '
#                                      'TARGET="_blank" TITLE="Bay Area American '
#                                      'Heart Association" REL="noreferrer '
#                                      'noopener nofollow noopener noreferrer '
#                                      'nofollow">website</A> for courses and '
#                                      'prices.\xa0<SPAN '
#                                      'CLASS="Apple-converted-space">\xa0'
#                                      '</SPAN>This course is for those who do '
#                                      'not require an official certification '
#                                      'card.</P>\n'
#                                      '<P CLASS="p1"><STRONG>Who should\xa0'
#                                      '<SPAN CLASS="s1">NOT</SPAN>\xa0take this '
#                                      'CPR class</STRONG><BR>Medical or '
#                                      'healthcare professionals must take the '
#                                      'BLS class. Childcare providers who need '
#                                      'EMSA certification must take the '
#                                      'Pediatric First-aid/CPR course.</P>\n'
#                                      '<P CLASS="p4"><STRONG>Free Keychain CPR '
#                                      'Breathing Mask ($10 '
#                                      'value)</STRONG><BR>On the day of your '
#                                      'class, you can check in with your mobile '
#                                      'phone on Facebook, Foursquare, or Yelp '
#                                      'and receive a free keychain CPR '
#                                      'mask.</P>\n'
#                                      '<P '
#                                      'CLASS="p4"><STRONG>Classroom</STRONG><BR>Children '
#                                      'are not allowed in the classroom. For '
#                                      'your convenience we offer free tea, '
#                                      'granola bars, and a phone charging '
#                                      'station.</P>\n'
#                                      '<P><STRONG>Questions?</STRONG><BR>Give '
#                                      'us a call at 415-437-1600</P>',
#                              'text': 'FREE CPR Class by Sports Basement\n'
#                                      'Course Name:\xa0STS CPRDescription: CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, choke-savingLength:\xa02 '
#                                      'hoursCourse Price:\xa0$0Cancellation '
#                                      'Policy: Please let us know if you want '
#                                      'to cancel, so we can give your spot to '
#                                      'someone else.\n'
#                                      'CertificationThis course is not by the '
#                                      'American Heart Association or the '
#                                      'American Red Cross. If you need to have '
#                                      'an official certification card for a '
#                                      'work requirement, you would need to take '
#                                      'an American Heart Association course. '
#                                      'View our website for courses and '
#                                      'prices.\xa0\xa0This course is for those '
#                                      'who do not require an official '
#                                      'certification card.\n'
#                                      'Who should\xa0NOT\xa0take this CPR '
#                                      'classMedical or healthcare professionals '
#                                      'must take the BLS class. Childcare '
#                                      'providers who need EMSA certification '
#                                      'must take the Pediatric First-aid/CPR '
#                                      'course.\n'
#                                      'Free Keychain CPR Breathing Mask ($10 '
#                                      'value)On the day of your class, you can '
#                                      'check in with your mobile phone on '
#                                      'Facebook, Foursquare, or Yelp and '
#                                      'receive a free keychain CPR mask.\n'
#                                      'ClassroomChildren are not allowed in the '
#                                      'classroom. For your convenience we offer '
#                                      'free tea, granola bars, and a phone '
#                                      'charging station.\n'
#                                      'Questions?Give us a call at '
#                                      '415-437-1600'},
#              'end': {'local': '2018-12-25T11:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-12-25T19:00:00Z'},
#              'format_id': '9',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '50657163941',
#              'is_externally_ticketed': False,
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 1060,
#                                     'top_left': {'x': 0, 'y': 106},
#                                     'width': 2120},
#                       'edge_color': '#ddd7d2',
#                       'edge_color_set': True,
#                       'id': '50349672',
#                       'original': {'height': 1414,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50349672%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=7dc423cb8aded7c260417cf8029876d1',
#                                    'width': 2121},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50349672%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=9390581ae234be7e3f30723abaf73f33'},
#              'logo_id': '50349672',
#              'name': {'html': 'Sports Basement Free CPR Class in San Francisco',
#                       'text': 'Sports Basement Free CPR Class in San '
#                               'Francisco'},
#              'online_event': False,
#              'organization_id': '14268435757',
#              'organizer_id': '1086926597',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/50657163941/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-12-25T09:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-12-25T17:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '7003',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50657163941?aff=ebapi',
#              'venue_id': '974499',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '107',
#              'changed': '2018-09-25T18:44:35Z',
#              'created': '2018-09-25T18:44:14Z',
#              'currency': 'USD',
#              'description': {'html': '<H2><STRONG>FREE CPR Class by Sports '
#                                      'Basement</STRONG></H2>\n'
#                                      '<P CLASS="p1"><STRONG>Course '
#                                      'Name</STRONG>:\xa0STS '
#                                      'CPR<BR><STRONG>Description:</STRONG> CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, '
#                                      'choke-saving<BR><STRONG>Length:</STRONG>\xa0'
#                                      '2 hours<BR><STRONG>Course '
#                                      'Price</STRONG>:\xa0'
#                                      '$0<BR><STRONG>Cancellation '
#                                      'Policy:</STRONG> Please let us know if '
#                                      'you want to cancel, so we can give your '
#                                      'spot to someone else.<BR></P>\n'
#                                      '<P '
#                                      'CLASS="p1"><STRONG>Certification</STRONG><BR>This '
#                                      'course is not by the American Heart '
#                                      'Association or the American Red Cross. '
#                                      'If you need to have an official '
#                                      'certification card for a work '
#                                      'requirement, you would need to take an '
#                                      'American Heart Association course. View '
#                                      'our <A HREF="http://www.bayareacpr.org" '
#                                      'TARGET="_blank" TITLE="Bay Area American '
#                                      'Heart Association" REL="noreferrer '
#                                      'noopener nofollow noopener noreferrer '
#                                      'nofollow">website</A> for courses and '
#                                      'prices.\xa0<SPAN '
#                                      'CLASS="Apple-converted-space">\xa0'
#                                      '</SPAN>This course is for those who do '
#                                      'not require an official certification '
#                                      'card.</P>\n'
#                                      '<P CLASS="p1"><STRONG>Who should\xa0'
#                                      '<SPAN CLASS="s1">NOT</SPAN>\xa0take this '
#                                      'CPR class</STRONG><BR>Medical or '
#                                      'healthcare professionals must take the '
#                                      'BLS class. Childcare providers who need '
#                                      'EMSA certification must take Pediatric '
#                                      'First-aid/CPR course.</P>\n'
#                                      '<P CLASS="p4"><STRONG>Free Keychain CPR '
#                                      'Breathing Mask ($10 '
#                                      'value)</STRONG><BR>On the day of your '
#                                      'class, you can check in with your mobile '
#                                      'phone on Facebook, Foursquare, or Yelp '
#                                      'and receive a free keychain CPR '
#                                      'mask.</P>\n'
#                                      '<P '
#                                      'CLASS="p4"><STRONG>Classroom</STRONG><BR>Children '
#                                      'are not allowed in the classroom. For '
#                                      'your convenience we offer free tea, '
#                                      'granola bars, and a phone charging '
#                                      'station.</P>\n'
#                                      '<P><STRONG>Questions?</STRONG><BR>Give '
#                                      'us a call at 415-437-1600</P>',
#                              'text': 'FREE CPR Class by Sports Basement\n'
#                                      'Course Name:\xa0STS CPRDescription: CPR '
#                                      'for adults, children, and infants, AED '
#                                      'use, choke-savingLength:\xa02 '
#                                      'hoursCourse Price:\xa0$0Cancellation '
#                                      'Policy: Please let us know if you want '
#                                      'to cancel, so we can give your spot to '
#                                      'someone else.\n'
#                                      'CertificationThis course is not by the '
#                                      'American Heart Association or the '
#                                      'American Red Cross. If you need to have '
#                                      'an official certification card for a '
#                                      'work requirement, you would need to take '
#                                      'an American Heart Association course. '
#                                      'View our website for courses and '
#                                      'prices.\xa0\xa0This course is for those '
#                                      'who do not require an official '
#                                      'certification card.\n'
#                                      'Who should\xa0NOT\xa0take this CPR '
#                                      'classMedical or healthcare professionals '
#                                      'must take the BLS class. Childcare '
#                                      'providers who need EMSA certification '
#                                      'must take Pediatric First-aid/CPR '
#                                      'course.\n'
#                                      'Free Keychain CPR Breathing Mask ($10 '
#                                      'value)On the day of your class, you can '
#                                      'check in with your mobile phone on '
#                                      'Facebook, Foursquare, or Yelp and '
#                                      'receive a free keychain CPR mask.\n'
#                                      'ClassroomChildren are not allowed in the '
#                                      'classroom. For your convenience we offer '
#                                      'free tea, granola bars, and a phone '
#                                      'charging station.\n'
#                                      'Questions?Give us a call at '
#                                      '415-437-1600'},
#              'end': {'local': '2019-02-15T11:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2019-02-15T19:00:00Z'},
#              'format_id': '9',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '50659001437',
#              'is_externally_ticketed': False,
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 1060,
#                                     'top_left': {'x': 0, 'y': 106},
#                                     'width': 2120},
#                       'edge_color': '#ddd7d2',
#                       'edge_color_set': True,
#                       'id': '50351797',
#                       'original': {'height': 1414,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351797%2F14268435757%2F1%2Foriginal.jpg?auto=compress&s=6a6932b60e54d3ca854e39e06cbf7d8f',
#                                    'width': 2121},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50351797%2F14268435757%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C106%2C2120%2C1060&s=f774becba1a31a7c1d2f6c1ca0288d0f'},
#              'logo_id': '50351797',
#              'name': {'html': 'Sports Basement Free CPR Class in San Francisco',
#                       'text': 'Sports Basement Free CPR Class in San '
#                               'Francisco'},
#              'online_event': False,
#              'organization_id': '14268435757',
#              'organizer_id': '1086926597',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/50659001437/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2019-02-15T09:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2019-02-15T17:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '7003',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50659001437?aff=ebapi',
#              'venue_id': '974499',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '101',
#              'changed': '2018-09-26T17:27:00Z',
#              'created': '2018-09-20T19:21:57Z',
#              'currency': 'USD',
#              'description': {'html': '<P>Looking for a new space to work from '
#                                      'for the day? Calling entrepreneurs, '
#                                      'hackers, digital nomads, and startup '
#                                      'founders to join us at\xa0Startup '
#                                      "Basecamp's community space\xa0for our "
#                                      'weekly\xa0<STRONG>FREE COWORKING '
#                                      'PASS.\xa0</STRONG></P>\n'
#                                      '<P><STRONG>STARTUP BASECAMP is the first '
#                                      'Startup Hotel offering a unique '
#                                      'short-term co-living &amp; co-working '
#                                      'solution in San Francisco for startup '
#                                      'professionals and entrepreneurs.\xa0'
#                                      '</STRONG></P>\n'
#                                      "<P>There's hot coffee, high-speed wifi, "
#                                      'and a great group of like-minded people '
#                                      'ready to connect.\xa0Our innovative '
#                                      'community of entrepreneurs is diverse '
#                                      'and international, giving you the chance '
#                                      'to meet and collaborate with people from '
#                                      'across the globe.\xa0</P>\n'
#                                      '<P>Work indoors or catch some fun &amp; '
#                                      'sun in our cool outdoor lounge!\xa0</P>\n'
#                                      '<P><STRONG>Space is limited so we kindly '
#                                      'ask you to RSVP and you update your\xa0'
#                                      'RSVP if your plans change and you can no '
#                                      'longer make it :)\xa0</STRONG></P>\n'
#                                      '<P><IMG '
#                                      'SRC="https://cdn.evbuc.com/eventlogos/179582397/collagesbc.jpg"></P>\n'
#                                      '<P><STRONG>ABOUT STARTUP '
#                                      'BASECAMP:</STRONG></P>\n'
#                                      '<P>As the<STRONG>\xa0First Startup Hotel '
#                                      'in San Francisco\xa0</STRONG>&amp; an '
#                                      'industry leader in the space\xa0'
#                                      '<STRONG>-\xa0</STRONG><STRONG><A '
#                                      'HREF="https://www.eventbrite.com/e/silicon-valley-survival-program-tickets-26476289294" '
#                                      'TARGET="_blank" REL="noopener noreferrer '
#                                      'noopener noreferrer">Startup '
#                                      'Basecamp</A>\xa0</STRONG>pioneered the '
#                                      'concept of a\xa0<STRONG>CO-LIVING &amp; '
#                                      'CO-WORKING HOTEL </STRONG>providing\xa0a '
#                                      'quality short-term solution for '
#                                      'startup\xa0professionals and\xa0'
#                                      'entrepreneurs looking for both a '
#                                      'reasonably priced place to stay and a '
#                                      'supportive community while they visit '
#                                      'Silicon Valley.</P>\n'
#                                      '<P><STRONG><A '
#                                      'HREF="http://www.startupbasecamp.org/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">JOIN OUR COMMUNITY</A>\xa0'
#                                      'TODAY!</STRONG></P>',
#                              'text': 'Looking for a new space to work from for '
#                                      'the day? Calling entrepreneurs, hackers, '
#                                      'digital nomads, and startup founders to '
#                                      "join us at\xa0Startup Basecamp's "
#                                      'community space\xa0for our weekly\xa0'
#                                      'FREE COWORKING PASS.\xa0\n'
#                                      'STARTUP BASECAMP is the first Startup '
#                                      'Hotel offering a unique short-term '
#                                      'co-living & co-working solution in San '
#                                      'Francisco for startup professionals and '
#                                      'entrepreneurs.\xa0\n'
#                                      "There's hot coffee, high-speed wifi, and "
#                                      'a great group of like-minded people '
#                                      'ready to connect.\xa0Our innovative '
#                                      'community of entrepreneurs is diverse '
#                                      'and international, giving you the chance '
#                                      'to meet and collaborate with people from '
#                                      'across the globe.\xa0\n'
#                                      'Work indoors or catch some fun & sun in '
#                                      'our cool outdoor lounge!\xa0\n'
#                                      'Space is limited so we kindly ask you to '
#                                      'RSVP and you update your\xa0RSVP if your '
#                                      'plans change and you can no longer make '
#                                      'it :)\xa0\n'
#                                      '\n'
#                                      'ABOUT STARTUP BASECAMP:\n'
#                                      'As the\xa0First Startup Hotel in San '
#                                      'Francisco\xa0& an industry leader in the '
#                                      'space\xa0-\xa0Startup Basecamp\xa0'
#                                      'pioneered the concept of a\xa0CO-LIVING '
#                                      '& CO-WORKING HOTEL providing\xa0a '
#                                      'quality short-term solution for '
#                                      'startup\xa0professionals and\xa0'
#                                      'entrepreneurs looking for both a '
#                                      'reasonably priced place to stay and a '
#                                      'supportive community while they visit '
#                                      'Silicon Valley.\n'
#                                      'JOIN OUR COMMUNITY\xa0TODAY!'},
#              'end': {'local': '2018-10-11T18:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-10-12T01:30:00Z'},
#              'format_id': '10',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '50504043955',
#              'is_externally_ticketed': False,
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': True,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 1024,
#                                     'top_left': {'x': 0, 'y': 241},
#                                     'width': 2048},
#                       'edge_color': '#73513c',
#                       'edge_color_set': True,
#                       'id': '44682865',
#                       'original': {'height': 1365,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44682865%2F180839473779%2F1%2Foriginal.jpg?auto=compress&s=eba5d78b1563551e3761028075d09922',
#                                    'width': 2048},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44682865%2F180839473779%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C241%2C2048%2C1024&s=92739948f4bf77721e164034788a1d8f'},
#              'logo_id': '44682865',
#              'name': {'html': 'STARTUP BASECAMP: FREE CO-WORKING PASS',
#                       'text': 'STARTUP BASECAMP: FREE CO-WORKING PASS'},
#              'online_event': False,
#              'organization_id': '180839473779',
#              'organizer_id': '10966312574',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/50504043955/',
#              'series_id': '45958274436',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-10-11T09:30:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-10-11T16:30:00Z'},
#              'status': 'live',
#              'subcategory_id': '1001',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/startup-basecamp-free-co-working-pass-tickets-50504043955?aff=ebapi',
#              'venue_id': '17318909',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '108',
#              'changed': '2018-10-01T13:47:29Z',
#              'created': '2018-08-25T22:01:01Z',
#              'currency': 'USD',
#              'description': {'html': '<H2>Learn to Wield a Light Saber!</H2>\n'
#                                      '<P>At LudoSport, we teach students how '
#                                      'to do actual improvisational sparring '
#                                      'with light sabers (no choreography '
#                                      'here!). With practice, students are able '
#                                      'to safely duel with one another, and '
#                                      'even eventually compete in official '
#                                      'LudoSport tournaments.</P>\n'
#                                      '<P>This is a special introductory class '
#                                      'to give participants an overview of what '
#                                      "we're all about. You'll be introduced to "
#                                      'the fundamentals of LudoSport Sporting '
#                                      'Light Saber Combat: basic stances, '
#                                      'movement, offensive and defensive '
#                                      'techniques.</P>\n'
#                                      "<P>You'll also get a chance to spar at "
#                                      'the end of every class (time '
#                                      'permitting)!</P>\n'
#                                      '<P><STRONG>Price: FREE!\xa0 '
#                                      '</STRONG></P>\n'
#                                      '<P><STRONG>HOWEVER...</STRONG>since we '
#                                      'have a limited number of sabers '
#                                      'available for use, in order to guarantee '
#                                      'that we have enough sabers for everyone, '
#                                      'we ask that you put down a deposit by '
#                                      "purchasing a $5 ticket — we'll refund it "
#                                      'when you arrive.</P>\n'
#                                      '<H2>Please Bring:</H2>\n'
#                                      '<H3 CLASS="MsoNormal">Comfortable '
#                                      'sportswear and footwear.\xa0<BR></H3>\n'
# ...
#                                      'HREF="https://www.meetup.com/singleprofessionals/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">Single Professionals Internet '
#                                      'Network (SPiN</A>);\xa0<A '
#                                      'HREF="https://www.meetup.com/Cougar-Parties-Cruises/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">Cougar Parties</A>,\xa0<A '
#                                      'HREF="https://www.meetup.com/Singles-Over-40-and-Fun/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">40+ Singles</A>,\xa0<A '
#                                      'HREF="https://www.meetup.com/singlenprofessionals/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">Single n’ Professional</A>,\xa0'
#                                      '<A '
#                                      'HREF="https://www.meetup.com/Lifestyle-Parties-Hiking-Meetups/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">Lifestyle Parties</A>,\xa0'
#                                      '<SPAN><A '
#                                      'HREF="http://www.getalovelife.net/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow"><SPAN><SPAN>Get a Love '
#                                      'Life!</SPAN></SPAN></A></SPAN></EM>\xa0'
#                                      'and many others.</P>',
#                              'text': 'San Francisco’s most exciting singles '
#                                      'event of the Fall Season is in the '
#                                      'lovely Golden Gate Ballroom of the '
#                                      'Marriott Fisherman’s Wharf! $15/advance '
#                                      '(by Oct 12) or $20 cash at the door '
#                                      'includes dancing to your favorite hits. '
#                                      'Dressy attire requested. Adults of all '
#                                      'ages welcome. Saturday October 13, 2018, '
#                                      '8pm-12.\n'
#                                      'LOCATION: Marriott Hotel Fisherman’s '
#                                      'Wharf, Golden Gate Ballroom, 1250 '
#                                      'Columbus Avenue at Bay Street, San '
#                                      'Francisco CA 94133. Some free street '
#                                      'parking. Lowest priced paid parking is '
#                                      'at Anchorage Square Parking Lot, 500 '
#                                      'Beach Street.\n'
#                                      'CO-SPONSORED by\xa0The Society of Single '
#                                      'Professionals, the world’s largest '
#                                      'non-profit singles organization; Singles '
#                                      'Supper Club,\xa0San Francisco '
#                                      'Singles,\xa0Bay Area Single Boomers,\xa0'
#                                      'Single Professionals Internet Network '
#                                      '(SPiN);\xa0Cougar Parties,\xa040+ '
#                                      'Singles,\xa0Single n’ Professional,\xa0'
#                                      'Lifestyle Parties,\xa0Get a Love '
#                                      'Life!\xa0and many others.'},
#              'end': {'local': '2018-10-14T00:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-10-14T07:00:00Z'},
#              'format_id': '11',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '51111284227',
#              'is_externally_ticketed': False,
#              'is_free': False,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 300,
#                                     'top_left': {'x': 0, 'y': 69},
#                                     'width': 600},
#                       'edge_color': '#ffffff',
#                       'edge_color_set': True,
#                       'id': '50924415',
#                       'original': {'height': 449,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50924415%2F12663738963%2F1%2Foriginal.jpg?auto=compress&s=26c2527478493ad7605b63e8f230594d',
#                                    'width': 600},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50924415%2F12663738963%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C69%2C600%2C300&s=f3d60afdb0880a911ef6a98f828464a9'},
#              'logo_id': '50924415',
#              'name': {'html': 'THE FALL BALL', 'text': 'THE FALL BALL'},
#              'online_event': False,
#              'organization_id': '12663738963',
#              'organizer_id': '11999337482',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/51111284227/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-10-13T20:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-10-14T03:00:00Z'},
#              'status': 'live',
#              'subcategory_id': None,
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/the-fall-ball-tickets-51111284227?aff=ebapi',
#              'venue_id': '18882461',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '105',
#              'changed': '2018-10-07T21:12:44Z',
#              'created': '2018-10-07T21:12:37Z',
#              'currency': 'USD',
#              'description': {'html': '<P>The ladies of Chardonnay get '
#                                      'humorously indecent in this brand new '
#                                      'big, buttery, full-bawdied sketch comedy '
#                                      'show. "The Female Bawdy Show" is a '
#                                      'raucous romp through modern tales of '
#                                      'ribaldry playing for 4 nights only. '
#                                      '<BR>Loin tingling highlights include '
#                                      'adult women pony lovers, British '
#                                      'S.T.D’s, drop crotch pants, and an '
#                                      'Instant Pot. We go there. Come both '
#                                      'ladies and gents and let out your inner '
#                                      'bawdy beast with San Francisco’s longest '
#                                      'running all-female sketch group this '
#                                      'November!</P>\n'
#                                      '<P>Playing November 9, 10, 16, 17 at '
#                                      '8pm.<BR>Show is about 1 hour with no '
#                                      'intermission.</P>\n'
#                                      '<P><BR></P>\n'
#                                      '<HR>\n'
#                                      '<H2>PianoFight’s not just a theater, '
#                                      'it’s also a restaurant and bar!</H2>\n'
#                                      '<P>★★★★½ on Yelp<BR>★★★★½ on '
#                                      'Google<BR>★★★★★ on Facebook</P>\n'
#                                      '<P><EM>“Reasonably priced New American '
#                                      'bites and cocktails in an unpretentious '
#                                      'setting” - Zagat</EM></P>\n'
#                                      '<P><EM>“The best party spot in the '
#                                      'neighborhood” - The Bay '
#                                      'Bridged</EM></P>\n'
#                                      '<P><EM>“A hot SF scene” - SF '
#                                      'Chronicle</EM></P>\n'
#                                      '<P>If you plan on <A '
#                                      'HREF="https://www.pianofight.com/menu" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">dining</A>, we recommend you '
#                                      'arrive 1.5 hours early so you have '
#                                      'plenty of time to eat before the show. '
#                                      'Restaurant seating is first come first '
#                                      'serve. Drinks are always allowed in the '
#                                      'theaters.</P>\n'
#                                      '<P>PARKING<BR>Street parking is free '
#                                      'after 6pm. We’re located 2 blocks from '
#                                      'Powell BART, numerous muni lines and '
#                                      'there are 3 parking lots within 1 '
#                                      'block.</P>',
#                              'text': 'The ladies of Chardonnay get humorously '
#                                      'indecent in this brand new big, buttery, '
#                                      'full-bawdied sketch comedy show. "The '
#                                      'Female Bawdy Show" is a raucous romp '
#                                      'through modern tales of ribaldry playing '
#                                      'for 4 nights only. Loin tingling '
#                                      'highlights include adult women pony '
#                                      'lovers, British S.T.D’s, drop crotch '
#                                      'pants, and an Instant Pot. We go there. '
#                                      'Come both ladies and gents and let out '
#                                      'your inner bawdy beast with San '
#                                      'Francisco’s longest running all-female '
#                                      'sketch group this November!\n'
#                                      'Playing November 9, 10, 16, 17 at '
#                                      '8pm.Show is about 1 hour with no '
#                                      'intermission.\n'
#                                      '\n'
#                                      '\n'
#                                      'PianoFight’s not just a theater, it’s '
#                                      'also a restaurant and bar!\n'
#                                      '★★★★½ on Yelp★★★★½ on Google★★★★★ on '
#                                      'Facebook\n'
#                                      '“Reasonably priced New American bites '
#                                      'and cocktails in an unpretentious '
#                                      'setting” - Zagat\n'
#                                      '“The best party spot in the '
#                                      'neighborhood” - The Bay Bridged\n'
#                                      '“A hot SF scene” - SF Chronicle\n'
#                                      'If you plan on dining, we recommend you '
#                                      'arrive 1.5 hours early so you have '
#                                      'plenty of time to eat before the show. '
#                                      'Restaurant seating is first come first '
#                                      'serve. Drinks are always allowed in the '
#                                      'theaters.\n'
#                                      'PARKINGStreet parking is free after 6pm. '
#                                      'We’re located 2 blocks from Powell BART, '
#                                      'numerous muni lines and there are 3 '
#                                      'parking lots within 1 block.'},
#              'end': {'local': '2018-11-09T21:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-11-10T05:30:00Z'},
#              'format_id': '6',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '51122804685',
#              'is_externally_ticketed': False,
#              'is_free': False,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': True,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 400,
#                                     'top_left': {'x': 0, 'y': 0},
#                                     'width': 800},
#                       'edge_color': '#38b2b7',
#                       'edge_color_set': True,
#                       'id': '50940555',
#                       'original': {'height': 400,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50940555%2F144154840397%2F1%2Foriginal.jpg?auto=compress&s=2493fecbc0f3c730a359338f56f51d4b',
#                                    'width': 800},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F50940555%2F144154840397%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C800%2C400&s=bf5bb37dce0ca27ca6dbc9b9139f3ce8'},
#              'logo_id': '50940555',
#              'name': {'html': 'The Female Bawdy Show',
#                       'text': 'The Female Bawdy Show'},
#              'online_event': False,
#              'organization_id': '115446603665',
#              'organizer_id': '7317491375',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/51122804685/',
#              'series_id': '51122507797',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-11-09T20:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-11-10T04:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '5010',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/the-female-bawdy-show-tickets-51122804685?aff=ebapi',
#              'venue_id': '13596593',
#              'version': '3.0.0'}],
#  'location': {'address': 'san francisco',
#               'augmented_location': {'city': 'San Francisco',
#                                      'country': 'United States',
#                                      'region': 'California'},
#               'latitude': '37.774930',
#               'longitude': '-122.419416',
#               'within': '9.91082317248'},
#  'pagination': {'has_more_items': True,
#                 'object_count': 116,
#                 'page_count': 3,
#                 'page_number': 1,
#                 'page_size': 50}}

# %%
# Create the following variables and set them to empty lists:
    # name_list, start_datetime_list, end_datetime_list, url_list
name_list = []
start_datetime_list = []
end_datetime_list = []
url_list = []

# Loop through each response event and 
    # append the name, times, and url to the appropriate lists declared above.
for i in np.arange(len(response["events"])):
    name_list.append(response["events"][i]["name"]["text"])
    end_datetime_list.append(response["events"][i]['end']['local'])
    start_datetime_list.append(response["events"][i]['start']['local'])
    url_list.append(response["events"][i]['url'])
    
# Print one of the lists to verify correct input.
url_list
# Out:
# ['https://www.eventbrite.com/e/product-marketing-workshop-building-a-saas-pricing-and-packaging-foundation-for-growth-tickets-50554218027?aff=ebapi',
#  'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50658880074?aff=ebapi',
#  'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50657163941?aff=ebapi',
#  'https://www.eventbrite.com/e/sports-basement-free-cpr-class-in-san-francisco-tickets-50659001437?aff=ebapi',
#  'https://www.eventbrite.com/e/startup-basecamp-free-co-working-pass-tickets-50504043955?aff=ebapi',
#  'https://www.eventbrite.com/e/free-outdoor-class-intro-to-light-saber-combat-tickets-49519460038?aff=ebapi',
#  'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-home-buying-webinar-tickets-50982603339?aff=ebapi',
#  'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-preparing-to-sell-in-the-new-year-class-tickets-50981560219?aff=ebapi',
#  'https://www.eventbrite.com/e/san-francisco-ca-free-redfin-preparing-to-sell-in-the-new-year-class-tickets-50982327514?aff=ebapi',
#  'https://www.eventbrite.com/e/salsa-dancing-and-free-class-party-on-sundays-in-sf-iheartmambo-must-arrive-early-and-take-beginner-tickets-44729268446?aff=ebapi',
#  'https://www.eventbrite.com/e/wordparty-tickets-50928780353?aff=ebapi',
#  'https://www.eventbrite.com/e/sweet-spark-shopping-party-with-girls-on-the-run-tickets-50544683509?aff=ebapi',
#  'https://www.eventbrite.com/e/bollywood-blast-tickets-50943469288?aff=ebapi',
#  'https://www.eventbrite.com/e/family-workshop-cooking-matters-20180906-tickets-48620899419?aff=ebapi',
#  'https://www.eventbrite.com/e/wave-watch-an-election-night-extravaganza-tickets-48678988164?aff=ebapi',
#  'https://www.eventbrite.com/e/the-grand-tour-monthly-party-tickets-48677828696?aff=ebapi',
#  'https://www.eventbrite.com/e/inessence-bachata-tuesdays-in-san-francisco-tickets-41799888592?aff=ebapi',
#  'https://www.eventbrite.com/e/gutter-swan-americana-happy-hour-tickets-49921098349?aff=ebapi',
#  'https://www.eventbrite.com/e/talking-simpsons-podcast-halloween-live-show-tickets-50667079599?aff=ebapi',
#  'https://www.eventbrite.com/e/the-warm-red-variety-show-tickets-50929467408?aff=ebapi',
#  'https://www.eventbrite.com/e/sleepover-with-sam-molly-tickets-51121186846?aff=ebapi',
#  'https://www.eventbrite.ca/e/da-vinci-decoded-tour-2019-registration-45842591425?aff=ebapi',
#  'https://www.eventbrite.com/e/travel-10-save-earn-with-members-only-booking-site-safr-registration-51112876991?aff=ebapi',
#  'https://www.eventbrite.com/e/fall-mixer-welcome-new-grads-all-alums-welcome-tickets-50533042691?aff=ebapi',
#  'https://www.eventbrite.com/e/sf-tri-club-indoor-cycling-series-iii-2018-17th-street-athletic-club-tickets-48622515252?aff=ebapi',
#  'https://www.eventbrite.com/e/shotz-the-musical-tickets-50717174434?aff=ebapi',
#  'https://www.eventbrite.com/e/david-gerard-signs-tickets-49457508740?aff=ebapi',
#  'https://www.eventbrite.com/e/drunk-theatre-tickets-50470022195?aff=ebapi',
#  'https://www.eventbrite.com/e/zero-waste-shopping-workshop-rainbow-grocery-tickets-43333064362?aff=ebapi',
#  'https://www.eventbrite.com/e/north-by-north-lobster-tickets-41324379331?aff=ebapi',
#  'https://www.eventbrite.com/e/lobster-actually-tickets-41324446532?aff=ebapi',
#  'https://www.eventbrite.com/e/without-you-im-nothing-in-drag-tickets-50232731452?aff=ebapi',
#  'https://www.eventbrite.com/e/yacht-rock-thursdays-tickets-49106500866?aff=ebapi',
#  'https://www.eventbrite.com/e/max-chanowitz-jazz-banshee-tickets-50426210152?aff=ebapi',
#  'https://www.eventbrite.com/e/the-sf-magic-hour-tickets-49162057036?aff=ebapi',
#  'https://www.eventbrite.com/e/mr-smiths-halloween-bash-2018-tickets-50494360993?aff=ebapi',
#  'https://www.eventbrite.com/e/the-funniest-show-in-san-francisco-tickets-50657281292?aff=ebapi',
#  'https://www.eventbrite.com/e/girls-leading-girls-community-party-and-fundraiser-tickets-50880811878?aff=ebapi',
#  'https://www.eventbrite.com/e/technically-funny-tickets-51122215924?aff=ebapi',
#  'https://www.eventbrite.com/e/normal-show-tickets-50143453419?aff=ebapi',
#  'https://www.eventbrite.com/e/missed-connections-tickets-50426035630?aff=ebapi',
#  'https://www.eventbrite.com/e/better-luck-next-time-tickets-50379477373?aff=ebapi',
#  'https://www.eventbrite.com/e/baby-sheriffs-tickets-50469279975?aff=ebapi',
#  'https://www.eventbrite.com/e/electric-brass-thursday-with-funky-spuds-tickets-50617602612?aff=ebapi',
#  'https://www.eventbrite.com/e/no-youre-drunk-the-drinking-game-comedy-show-tickets-50656800855?aff=ebapi',
#  'https://www.eventbrite.com/e/24th-annual-fall-native-plant-sale-tickets-50677276097?aff=ebapi',
#  'https://www.eventbrite.com/e/jackpot-an-evening-of-music-food-dancing-game-show-entertainment-tickets-51049312869?aff=ebapi',
#  'https://www.eventbrite.com/e/the-fall-ball-tickets-51111284227?aff=ebapi',
#  'https://www.eventbrite.com/e/the-female-bawdy-show-tickets-51122804685?aff=ebapi']

# %%
# Create a variable event_dict and set it to a dictionary for the data frame using 
    # lists created earlier from name, start date time, end date time, and url
event_dict = {'Event Name': name_list,
             'Start Time': start_datetime_list,
             'End Time': end_datetime_list,
             'URL': url_list}

# Create a new variable "event_data"
    # Set it to a new dataframe by using pandas to create a dataframe from event_dict
event_data = pd.DataFrame(event_dict)

# Show all rows of event_data
event_data.head(50)

# See if there's an interesting event you would like to attend?
# Out:
#                                            Event Name           Start Time  \
# 0   Product Marketing Workshop: Building a SaaS Pr...  2018-10-15T19:00:00
# 1     Sports Basement Free CPR Class in San Francisco  2019-01-15T09:00:00
# 2     Sports Basement Free CPR Class in San Francisco  2018-12-25T09:00:00
# 3     Sports Basement Free CPR Class in San Francisco  2019-02-15T09:00:00
# 4              STARTUP BASECAMP: FREE CO-WORKING PASS  2018-10-11T09:30:00
# 5     Free Outdoor Class: Intro to Light Saber Combat  2018-10-10T19:00:00
# 6   San Francisco, CA - Free Redfin Home Buying We...  2018-11-03T11:00:00
# 7   San Francisco, CA - Free Redfin Preparing to S...  2018-10-30T18:30:00
# 8   San Francisco, CA - Free Redfin Preparing to S...  2018-12-12T18:30:00
# 9   SALSA DANCING and FREE CLASS & PARTY on Sunday...  2018-10-28T19:00:00
# 10                                          WordParty  2018-10-16T19:00:00
# 11  Sweet & Spark Shopping Party with Girls on the...  2018-10-09T18:30:00
# 12                                    Bollywood Blast  2018-10-13T22:00:00
# 13          Family Workshop: Cooking Matters 20180906  2018-09-06T18:00:00
# 14         Wave Watch: An Election Night Extravaganza  2018-11-06T19:00:00
# 15                       The Grand Tour Monthly Party  2018-11-01T18:00:00
# 16        Inessence Bachata Tuesdays in SAN FRANCISCO  2018-10-09T20:00:00
# 17                   Gutter Swan Americana Happy Hour  2018-10-13T17:30:00
# 18       Talking Simpsons Podcast Halloween Live Show  2018-10-27T17:30:00
# 19                          The Warm Red Variety Show  2018-10-18T19:00:00
# 20                         Sleepover with Sam & Molly  2018-10-31T19:00:00
# 21                     DA VINCI (de)CODE(d) TOUR 2019  2019-08-24T13:00:00
# 22  Travel 10 Save & Earn with members only bookin...  2018-10-07T19:00:00
# 23  Fall Mixer - Welcome New Grads! (All Alums Wel...  2018-10-11T17:00:00
# 24  SF Tri Club Indoor Cycling Series III - 2018 @...  2018-08-08T19:00:00
# 25                                 Shotz: The Musical  2018-11-07T20:00:00
# 26                                David Gerard: Signs  2018-10-17T20:00:00
# 27                                      Drunk Theatre  2018-10-20T22:00:00
# 28      Zero Waste Shopping Workshop @Rainbow Grocery  2018-11-04T10:00:00
# 29                             North By North Lobster  2018-10-18T20:00:00
# 30                                  Lobster, Actually  2018-12-06T20:00:00
# 31                  Without You I'm Nothing (In Drag)  2018-11-10T22:00:00
# 32                               Yacht Rock Thursdays  2018-10-11T17:00:00
# 33                        Max Chanowitz: Jazz Banshee  2018-10-12T18:00:00
# 34                                  The SF Magic Hour  2018-10-29T20:00:00
# 35                    Mr. Smith's Halloween Bash 2018  2018-10-27T21:00:00
# 36                 The Funniest Show In San Francisco  2018-10-13T20:00:00
# 37  Girls Leading Girls Community Party and Fundra...  2018-12-05T18:30:00
# 38                                  Technically Funny  2018-11-03T16:30:00
# 39                                        Normal Show  2018-11-02T19:00:00
# 40                                 Missed Connections  2018-10-17T21:00:00
# 41                             Better Luck Next Time!  2018-10-09T19:00:00
# 42                                      Baby Sheriffs  2018-10-25T19:00:00
# 43           Electric Brass Thursday with Funky Spuds  2018-10-11T22:00:00
# 44    No, You're Drunk: The Drinking Game Comedy Show  2018-10-12T20:00:00
# 45                 24th Annual Fall Native Plant Sale  2018-10-27T11:00:00
# 46  Jackpot! An Evening of Music, Food, Dancing & ...  2018-11-02T19:00:00
# 47                                      THE FALL BALL  2018-10-13T20:00:00
# 48                              The Female Bawdy Show  2018-11-09T20:00:00
#
#                End Time                                                URL
# 0   2018-10-15T22:00:00  https://www.eventbrite.com/e/product-marketing...
# 1   2019-01-15T11:00:00  https://www.eventbrite.com/e/sports-basement-f...
# 2   2018-12-25T11:00:00  https://www.eventbrite.com/e/sports-basement-f...
# 3   2019-02-15T11:00:00  https://www.eventbrite.com/e/sports-basement-f...
# 4   2018-10-11T18:30:00  https://www.eventbrite.com/e/startup-basecamp-...
# 5   2018-10-10T21:00:00  https://www.eventbrite.com/e/free-outdoor-clas...
# 6   2018-11-03T12:00:00  https://www.eventbrite.com/e/san-francisco-ca-...
# 7   2018-10-30T20:30:00  https://www.eventbrite.com/e/san-francisco-ca-...
# 8   2018-12-12T20:30:00  https://www.eventbrite.com/e/san-francisco-ca-...
# 9   2018-10-28T23:00:00  https://www.eventbrite.com/e/salsa-dancing-and...
# 10  2018-10-16T21:30:00  https://www.eventbrite.com/e/wordparty-tickets...
# 11  2018-10-09T20:30:00  https://www.eventbrite.com/e/sweet-spark-shopp...
# 12  2018-10-14T02:00:00  https://www.eventbrite.com/e/bollywood-blast-t...
# 13  2018-10-11T20:00:00  https://www.eventbrite.com/e/family-workshop-c...
# 14  2018-11-06T20:30:00  https://www.eventbrite.com/e/wave-watch-an-ele...
# 15  2018-11-01T20:00:00  https://www.eventbrite.com/e/the-grand-tour-mo...
# 16  2018-10-09T21:00:00  https://www.eventbrite.com/e/inessence-bachata...
# 17  2018-10-13T19:30:00  https://www.eventbrite.com/e/gutter-swan-ameri...
# 18  2018-10-27T18:30:00  https://www.eventbrite.com/e/talking-simpsons-...
# 19  2018-10-18T20:30:00  https://www.eventbrite.com/e/the-warm-red-vari...
# 20  2018-10-31T20:30:00  https://www.eventbrite.com/e/sleepover-with-sa...
# 21  2019-09-01T09:30:00  https://www.eventbrite.ca/e/da-vinci-decoded-t...
# 22  2018-10-07T19:30:00  https://www.eventbrite.com/e/travel-10-save-ea...
# 23  2018-10-11T19:00:00  https://www.eventbrite.com/e/fall-mixer-welcom...
# 24  2018-10-19T22:00:00  https://www.eventbrite.com/e/sf-tri-club-indoo...
# 25  2018-11-07T21:30:00  https://www.eventbrite.com/e/shotz-the-musical...
# 26  2018-10-17T21:30:00  https://www.eventbrite.com/e/david-gerard-sign...
# 27  2018-10-20T23:30:00  https://www.eventbrite.com/e/drunk-theatre-tic...
# 28  2018-11-04T12:00:00  https://www.eventbrite.com/e/zero-waste-shoppi...
# 29  2018-10-18T21:30:00  https://www.eventbrite.com/e/north-by-north-lo...
# 30  2018-12-06T21:30:00  https://www.eventbrite.com/e/lobster-actually-...
# 31  2018-11-10T23:30:00  https://www.eventbrite.com/e/without-you-im-no...
# 32  2018-10-11T19:00:00  https://www.eventbrite.com/e/yacht-rock-thursd...
# 33  2018-10-12T20:00:00  https://www.eventbrite.com/e/max-chanowitz-jaz...
# 34  2018-10-29T21:30:00  https://www.eventbrite.com/e/the-sf-magic-hour...
# 35  2018-10-28T02:00:59  https://www.eventbrite.com/e/mr-smiths-hallowe...
# 36  2018-10-13T21:30:00  https://www.eventbrite.com/e/the-funniest-show...
# 37  2018-12-05T21:00:00  https://www.eventbrite.com/e/girls-leading-gir...
# 38  2018-11-03T18:00:00  https://www.eventbrite.com/e/technically-funny...
# 39  2018-11-02T20:30:00  https://www.eventbrite.com/e/normal-show-ticke...
# 40  2018-10-17T22:00:00  https://www.eventbrite.com/e/missed-connection...
# 41  2018-10-09T20:30:00  https://www.eventbrite.com/e/better-luck-next-...
# 42  2018-10-25T20:30:00  https://www.eventbrite.com/e/baby-sheriffs-tic...
# 43  2018-10-11T23:00:00  https://www.eventbrite.com/e/electric-brass-th...
# 44  2018-10-12T21:30:00  https://www.eventbrite.com/e/no-youre-drunk-th...
# 45  2018-10-27T16:00:00  https://www.eventbrite.com/e/24th-annual-fall-...
# 46  2018-11-02T23:00:00  https://www.eventbrite.com/e/jackpot-an-evenin...
# 47  2018-10-14T00:00:00  https://www.eventbrite.com/e/the-fall-ball-tic...
# 48  2018-11-09T21:30:00  https://www.eventbrite.com/e/the-female-bawdy-...
