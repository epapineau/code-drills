# %%
# Import necessary dependencies to make API requests
import requests
import json
import pprint as pp
import pandas as pd
import numpy as np

# Import your API key
from config import gkey

# %%
# Set a endpoint url with a target address of our campus
# 160 Spear St. San Francisco, CA 94105
location_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                'address=160 Spear St. San Francisco, CA 94105&key={0}').format(gkey)

# %%
# Run a request to the endpoint and convert the result to JSON
location_call = requests.get(location_url).json()

# Print the JSON
location_call
# Out:
# {'results': [{'address_components': [{'long_name': '160',
#      'short_name': '160',
#      'types': ['street_number']},
#     {'long_name': 'Spear Street',
#      'short_name': 'Spear St',
#      'types': ['route']},
#     {'long_name': 'South of Market',
#      'short_name': 'South of Market',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94105', 'short_name': '94105', 'types': ['postal_code']}],
#    'formatted_address': '160 Spear St, San Francisco, CA 94105, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.7915342,
#       'lng': -122.3934448},
#      'southwest': {'lat': 37.7910758, 'lng': -122.3940257}},
#     'location': {'lat': 37.7913654, 'lng': -122.3937412},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.7926539802915,
#       'lng': -122.3923862697085},
#      'southwest': {'lat': 37.7899560197085, 'lng': -122.3950842302915}}},
#    'place_id': 'ChIJtRff72SAhYARUDoKOtJcH2I',
#    'types': ['premise']}],
#  'status': 'OK'}

# %%
# Extract the latitude and longitude and store them in a variable named "campus"
lat = location_call['results'][0]['geometry']['location']['lat']
lng = location_call['results'][0]['geometry']['location']['lng']
campus = f"{lat}, {lng}"

# Print the latitude and longitude of our campus
campus
# Out:
# '37.7913654, -122.3937412'

# %%
# Set the base url for the google places search API
query_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Set the parameters so that the location is our campus
# and searching for Walgreens pharmacies by distance
params = {
    "keyword": 'Walgreens',
    "type": 'store',
    "location": campus,
    "rankby": "distance",
    "key": gkey
}

# Run a request using the parameters
response = requests.get(query_url, params = params)

# Print the response url
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword=Walgreens&type=store&location=37.7913654%2C+-122.3937412&rankby=distance&key=AIzaSyDMndtsBt9q0Ry5-Vfvfh1S9A10wAczcq4

# %%
# Convert the response to JSON
response = response.json()

# Print the newly converted JSON object in pretty format
pp.pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCKwEAAOEtcECrV-Id6ov6IYNoZvP-n31A-LdwfurpBbVjXN1opVWe6Xr9Ryv3ql7ulKFX5EV44632O2aZX5qutWpSzdKa1X-G-wfRiG4lK170F4Pc7dzbuoXalfH2pGiIwFpJzH-Xmoz_FIdAN_dz66WuLL-DUmkXlxYcn9cmyxk26oOAjRRki2iSIzYseQ74Q8WK5KBsNGKua0jGPvmdbqbBQw7UedMYML-oyX9LsJNevnA_LJ1ISWk57o-qpFmtm6-aMnX7S0qCE6Ulzf9cIjGeWgCey0nDmca3l2NtkWp5C9R1-3Ca3xJ54gE_3tZdS5Ttl12UIW2TVCl75DbMx0zhlskKqYyQIg2koa8kQQcRtcR4voel9dwMXW2dqH0YV-iCuLObpzX6tNWRyYHK1bKjMy4SEInTMsABMn_oXXJqsSGWRn8aFM9Yg_V4A3cW7YzJnO-NkUf5Aep-',
#  'results': [{'geometry': {'location': {'lat': 37.7925241, 'lng': -122.3944116},
#                            'viewport': {'northeast': {'lat': 37.79393872989272,
#                                                       'lng': -122.3929782201073},
#                                         'southwest': {'lat': 37.79123907010727,
#                                                       'lng': -122.3956778798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'e7798a969051c14331a1b756b921f37ac5c32739',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116925116332960548099/photos">Elliot '
#                                                 'Schwartz</a>'],
#                           'photo_reference': 'CmRaAAAA2CiZLcTxjGya_2wqSJSiUe_8ZKVKU_1f3IsBFWoleZ64rx7vUJGXAOXMAmaYwQV8KN5hs8isNtyaMszEg1d5669vDiliD34_H7JDedAyKLx-SeOBJp-x_3A86BaSGUGLEhDwaGOS94IoeEp_zbPtUX09GhT99tdtvs_4RlVcl5Upv6YTh496Vg',
#                           'width': 1920}],
#               'place_id': 'ChIJf6FLQmSAhYARR4Mlm480x_I',
#               'plus_code': {'compound_code': 'QJV4+26 South of Market, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQJV4+26'},
#               'price_level': 2,
#               'rating': 3.1,
#               'reference': 'ChIJf6FLQmSAhYARR4Mlm480x_I',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '88 Spear St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7900166, 'lng': -122.3975766},
#                            'viewport': {'northeast': {'lat': 37.79130867989272,
#                                                       'lng': -122.3961541701073},
#                                         'southwest': {'lat': 37.78860902010728,
#                                                       'lng': -122.3988538298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '4067b91a3db91f31305b838b2e65287da10f3b2c',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116019367058651967694/photos">Oskar '
#                                                 'Dez</a>'],
#                           'photo_reference': 'CmRaAAAAIgs747wsJIMK88uHIxPKRBClTrtiYaumqs-owXFyLXv-hIt_u5RxnZCLAJlSaauWTm1zQ3RqXRG0gY-hO4JC3KOdpEW2rwi0USJvrKSgAVhWfUsWYJv2sEN1aQtMJoKGEhBplvKjxiGQdSixT-jIANyLGhRVMsuw7ZnHLt7em_BsIsp5yCkqcw',
#                           'width': 4032}],
#               'place_id': 'ChIJf6FLQmSAhYARi_7kR33GJxw',
#               'plus_code': {'compound_code': 'QJR2+2X South of Market, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQJR2+2X'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJf6FLQmSAhYARi_7kR33GJxw',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '456 Mission St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7941922, 'lng': -122.3967974},
#                            'viewport': {'northeast': {'lat': 37.79555527989272,
#                                                       'lng': -122.3953399201073},
#                                         'southwest': {'lat': 37.79285562010728,
#                                                       'lng': -122.3980395798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '6e0cc42994ece54f7a63533808bb2b50e2710a78',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107602328530544278868/photos">Raymond '
#                                                 'Hamilton</a>'],
#                           'photo_reference': 'CmRaAAAASe6K1PwOlUNX9IR9K6Bbb2Xt_vfFDcZI48VVNWi_FQBBI8RzB0X2vFAWfCf9vCX-6VP3iN0H8XOif3uRCjyvNMVfK97MW8lRjqxjBcx6ZlMXK-vqzPUyISPIs96ahs55EhB_OzX4dpcGgXR4zU77XttTGhTN3xQaREibZ4ksQuDZMl6H5iaBsg',
#                           'width': 2048}],
#               'place_id': 'ChIJoTx8CmGAhYARdlZaf8-FfXU',
#               'plus_code': {'compound_code': 'QJV3+M7 Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQJV3+M7'},
#               'price_level': 2,
#               'rating': 3,
#               'reference': 'ChIJoTx8CmGAhYARdlZaf8-FfXU',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '33 Drumm St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.794152, 'lng': -122.3984671},
#                            'viewport': {'northeast': {'lat': 37.79560592989272,
#                                                       'lng': -122.3971400701073},
#                                         'southwest': {'lat': 37.79290627010727,
#                                                       'lng': -122.3998397298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '8c13e656a454c58b8093ac6534f0237bba3d9d2c',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1607,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114013528308167523915/photos">Stephen '
#                                                 'Cassidy</a>'],
#                           'photo_reference': 'CmRaAAAA9bDHZTYNQulIiRy-xHOk5hn6tCAExBiZeSISvh0mg2YvIFDVrZt0FhrXyJPH4bv0m4ej9U-wVZqH6HekYpDTXoRrpUQNCktrfuq_3JMJ4dAn65mirW23ZfxCmcgFShyfEhA4rsZ4Ri83onICyCtjLhvrGhT26kBqCDsf2P-76XzRsn8eO7LBsg',
#                           'width': 2375}],
#               'place_id': 'ChIJoTx8CmGAhYARHgkbjPDarmE',
#               'plus_code': {'compound_code': 'QJV2+MJ Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQJV2+MJ'},
#               'price_level': 2,
#               'rating': 3.1,
#               'reference': 'ChIJoTx8CmGAhYARHgkbjPDarmE',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '275 Sacramento St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7913435, 'lng': -122.4005096},
#                            'viewport': {'northeast': {'lat': 37.79267342989272,
#                                                       'lng': -122.3993086701073},
#                                         'southwest': {'lat': 37.78997377010727,
#                                                       'lng': -122.4020083298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '10e568926ba0a4290342e069c07b620e75dd3741',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109966714163678627601/photos">Kim '
#                                                 'W</a>'],
#                           'photo_reference': 'CmRaAAAABSp1xMRgJ9qpK5qCCU1xetp2k1QUM9EB_6YBOzyXi0U9LMXam8_TKXF1LXM37ytaCOMesprpJQ-aFb-b9QAQwE8doIrwzaYAyjmLjKV3DYJpxAiYXaAjXeyGZ375dt4jEhAudW_etnDXP5xoHOemUzgQGhRY2MNNJZbiMSuoPB-RYlTzPkwsUg',
#                           'width': 3024}],
#               'place_id': 'ChIJf6FLQmSAhYARwY6-BL12ODM',
#               'plus_code': {'compound_code': 'QHRX+GQ Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHRX+GQ'},
#               'price_level': 2,
#               'rating': 2.9,
#               'reference': 'ChIJf6FLQmSAhYARwY6-BL12ODM',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '100 Sansome St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7870788, 'lng': -122.4004599},
#                            'viewport': {'northeast': {'lat': 37.78850562989273,
#                                                       'lng': -122.3990075701073},
#                                         'southwest': {'lat': 37.78580597010728,
#                                                       'lng': -122.4017072298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'b7dab5f4e78fea729ee04b98ddfe6c91ba87b862',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116019367058651967694/photos">Oskar '
#                                                 'Dez</a>'],
#                           'photo_reference': 'CmRaAAAAwSt4NKShN5xf0KjNwVn-31d4p8qi7NGCwMjriv6k3HOkRWhwA90FyNyfQhC_LLczXkMX3txn96DJCauLi7XXGePZLg1wRFJQ3X9ewejetCrMeHbutIE_runnuECZ--scEhA-hB7gsG_U7xwPV22_8bqpGhQNGJGB5BW2-5CJIJa1U_yNzfL-tw',
#                           'width': 3024}],
#               'place_id': 'ChIJf6FLQmSAhYARRGtBjAoDpPI',
#               'plus_code': {'compound_code': 'QHPX+RR South of Market, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHPX+RR'},
#               'price_level': 2,
#               'rating': 3.7,
#               'reference': 'ChIJf6FLQmSAhYARRGtBjAoDpPI',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '116 New Montgomery St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.79207900000001,
#                                         'lng': -122.4025092},
#                            'viewport': {'northeast': {'lat': 37.79342117989273,
#                                                       'lng': -122.4012188201073},
#                                         'southwest': {'lat': 37.79072152010728,
#                                                       'lng': -122.4039184798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '378f13c5250c49e5f426e76bf395baf0735b2b75',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107721404123505875377/photos">albert '
#                                                 'lee</a>'],
#                           'photo_reference': 'CmRaAAAA1j7KbyfLjZ2Gegp_TTTcQoiwQ2801TFBIQV5kbx0WNKaJsmr02tsk6aqw8Qts7bF29_2fuiZwPXA2mGcvZ-mlMEbBl_Ee5HmdKrpK39KmOQeYkIUU-ZawmBJrdc8qNytEhBvOZP2pGnySKuU6TBdiHdnGhTVaNq9GymU_RVjshXF-4px-xR8Lw',
#                           'width': 4128}],
#               'place_id': 'ChIJf6FLQmSAhYARVkWUgyt06OY',
#               'plus_code': {'compound_code': 'QHRW+RX Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHRW+RX'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJf6FLQmSAhYARVkWUgyt06OY',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '300 Montgomery St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7894322, 'lng': -122.4041121},
#                            'viewport': {'northeast': {'lat': 37.79080287989272,
#                                                       'lng': -122.4026117201073},
#                                         'southwest': {'lat': 37.78810322010727,
#                                                       'lng': -122.4053113798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '0d9c1007208ab543dcee10f368b379aee2a53c2e',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105470727697681630412/photos">Steven '
#                                                 'Smith</a>'],
#                           'photo_reference': 'CmRaAAAAMEjNzQyB2QO7hkcmx5O5QS5rqUgaltJr1EGOutEebs28f9KWXkUY5NpC-pZOYmm8ReccYRK6LY3EbLZaQcIQxxrMYI11MZwfjxgNAC3ocm_Foa6GP2Pa-qwR7l9c2VNDEhAtrccc669QAsRuSetRo3rrGhT7icguWuRuH7tzWebVezL7ZcoVAA',
#                           'width': 3264}],
#               'place_id': 'ChIJf6FLQmSAhYARyZ_yR3ysnec',
#               'plus_code': {'compound_code': 'QHQW+Q9 Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHQW+Q9'},
#               'price_level': 2,
#               'rating': 3,
#               'reference': 'ChIJf6FLQmSAhYARyZ_yR3ysnec',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '141 Kearny St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7873501, 'lng': -122.4043357},
#                            'viewport': {'northeast': {'lat': 37.78860187989272,
#                                                       'lng': -122.4028602701073},
#                                         'southwest': {'lat': 37.78590222010727,
#                                                       'lng': -122.4055599298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '1315820b527a47b86647fa0b5dd4685e67e5d2a3',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 634,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102876421386970849527/photos">Wendel '
#                                                 'Tse</a>'],
#                           'photo_reference': 'CmRaAAAA07KoW5Z8K2yTS-voICaMiu0sQZsvUVC4xz7-qmmg2hXtp94308LwzqZVDMC2OOwv_zBAR8CKmnuiUEkAIe0rV-b6wVNah3INsWIvxYWO1-ZpL2_a0HF-Vf6lg7U1Ri3SEhDEIG6ghrYZvjppyCXp47ezGhRfGzR1nEhVn0PZAlvSwmAXR83ZCA',
#                           'width': 829}],
#               'place_id': 'ChIJnz3DmOmAhYARip1OrcTnzsU',
#               'plus_code': {'compound_code': 'QHPW+W7 Financial District, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHPW+W7'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJnz3DmOmAhYARip1OrcTnzsU',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '730 Market St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7851371, 'lng': -122.4062683},
#                            'viewport': {'northeast': {'lat': 37.78656312989272,
#                                                       'lng': -122.4050099701073},
#                                         'southwest': {'lat': 37.78386347010728,
#                                                       'lng': -122.4077096298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'df0cb8dca31ce7c3f018807feb7532567857755d',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103324954082747310612/photos">Photo51 '
#                                                 'bio</a>'],
#                           'photo_reference': 'CmRaAAAAt07dTxgAufX4RfPdoLv7Fa3wt3bvEGosWW5wqMGCQ_wttMehlprFpbvzcnBtzXY694ICmWG6uHpg2Poq4A0skcINtS9uhtuuvopqUGyKeJKp6-dII2keIGlMHD_HyGqsEhCp50FFgJAzlyGDztQY3clJGhTQafdDwydw4IMoWJ6r5AxOhK5OVQ',
#                           'width': 4032}],
#               'place_id': 'ChIJnz3DmOmAhYAR6KzN-i8pcrQ',
#               'plus_code': {'compound_code': 'QHPV+3F South of Market, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHPV+3F'},
#               'price_level': 2,
#               'rating': 3.5,
#               'reference': 'ChIJnz3DmOmAhYAR6KzN-i8pcrQ',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '825 Market St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7890564, 'lng': -122.4088043},
#                            'viewport': {'northeast': {'lat': 37.79041867989272,
#                                                       'lng': -122.4073465701073},
#                                         'southwest': {'lat': 37.78771902010728,
#                                                       'lng': -122.4100462298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '297409e375c918917ce3f6a46e645ade71fab231',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102876421386970849527/photos">Wendel '
#                                                 'Tse</a>'],
#                           'photo_reference': 'CmRaAAAAR5hugJEKAFo-Qo7Vf0ttV42xn4TC_Vfp2SoeBDlpU0kxThOyS1NINdMtUYO6Rk0WddDxVANlERp1LXxLtiYhX8VfVtil-8JCk34ZpH5OqmirkdA2nPLPbAOaX0BeaOmpEhBONG-HQzF97lACLOsCyks4GhRNjvhNwhqJrHFq1ZHrxa06RHfYxg',
#                           'width': 5312}],
#               'place_id': 'ChIJA-bql46AhYAR03-lTvmOYsM',
#               'plus_code': {'compound_code': 'QHQR+JF Lower Nob Hill, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHQR+JF'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJA-bql46AhYAR03-lTvmOYsM',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '459 Powell St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7860006, 'lng': -122.4083833},
#                            'viewport': {'northeast': {'lat': 37.78737557989272,
#                                                       'lng': -122.4068300701073},
#                                         'southwest': {'lat': 37.78467592010728,
#                                                       'lng': -122.4095297298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '97787e9b602e3205152c7117adcd780d73882436',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114873740045565907081/photos">Aidan '
#                                                 'Follestad</a>'],
#                           'photo_reference': 'CmRaAAAAVcd0laaJGzZo2uzS2-qhWWih9Uyzi85TpQed-MgDZmJoHfVS3V5ZCG2G7yOoXZlFqObthPeaJVTpaaCIFoD3LTfHzDGMNk9R_FapDKsnyrrZz19PryU2rlY3e4j866HXEhAq1zSGj1MjYP96EAjLM7emGhTMkyGXJsC0iRBfWwbSqvKM0nCknQ',
#                           'width': 4032}],
#               'place_id': 'ChIJezdhHIaAhYAR_bFtvYZAEXE',
#               'plus_code': {'compound_code': 'QHPR+CJ Tenderloin, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHPR+CJ'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJezdhHIaAhYAR_bFtvYZAEXE',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '135 Powell St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7982361, 'lng': -122.4085345},
#                            'viewport': {'northeast': {'lat': 37.79957222989272,
#                                                       'lng': -122.4072935201073},
#                                         'southwest': {'lat': 37.79687257010727,
#                                                       'lng': -122.4099931798928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '387b411fba390548ca7153e2149e1c923912d6e8',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107602328530544278868/photos">Raymond '
#                                                 'Hamilton</a>'],
#                           'photo_reference': 'CmRaAAAAvrLbERSXdzMIQSWCnuWDaQzWLlfXdHeeGIQlNXHIG_jSpIUJhdUu_mYxV9lMLO-QaEeaHWjbUufCC-tCPBSBubF69kEuYGMqEuPholZ0DPzd-alLAIXt-d8aYhxpKE1GEhALtqzamThrIDSOIPI6OV2xGhQyanLLHVxUnfxsl2Bm5Og_tU3zLg',
#                           'width': 2048}],
#               'place_id': 'ChIJhUuZwfOAhYAR5g_rQir4hwo',
#               'plus_code': {'compound_code': 'QHXR+7H Russian Hill, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHXR+7H'},
#               'price_level': 2,
#               'rating': 3,
#               'reference': 'ChIJhUuZwfOAhYAR5g_rQir4hwo',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '1344 Stockton St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7771238, 'lng': -122.395353},
#                            'viewport': {'northeast': {'lat': 37.77851877989272,
#                                                       'lng': -122.3939467701073},
#                                         'southwest': {'lat': 37.77581912010728,
#                                                       'lng': -122.3966464298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'bab4be48e3557be70b4600fe27882d113a9f3928',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101450005761361777403/photos">Jason '
#                                                 'McMinn</a>'],
#                           'photo_reference': 'CmRaAAAAXoQ3ykCY5IxeBquDUup9uXWAZEEj-A9Fbv9mJ7ALYz4JucAwCM3kZOQowqiIg8IkUrAkUHI8mHGnoZkGuENLMSg2CL4iT3l6zLGy9K1cLu516s_VIpzaiHTL4nztQR2iEhDH2hVYP202LJ4rvs1jOUKJGhQe_Tm5mtNKFBn3EQBlvNei5imy0A',
#                           'width': 4032}],
#               'place_id': 'ChIJH0m-fdZ_j4ARSK4i9dKeC_w',
#               'plus_code': {'compound_code': 'QJG3+RV South of Market, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQJG3+RV'},
#               'price_level': 2,
#               'rating': 3.5,
#               'reference': 'ChIJH0m-fdZ_j4ARSK4i9dKeC_w',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '670 4th St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7870257, 'lng': -122.4117263},
#                            'viewport': {'northeast': {'lat': 37.78832612989272,
#                                                       'lng': -122.4103666701073},
#                                         'southwest': {'lat': 37.78562647010727,
#                                                       'lng': -122.4130663298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '8acbfb1286e24e27c684bb4f5c80dae250d72690',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107166391841662743537/photos">Raz</a>'],
#                           'photo_reference': 'CmRaAAAA-f4JPnmBc3sdr295ugX5N7ALHQoABQ9SsYCCFZM04SsEMVrkHrGefQ9RcBu0-u88NEgZe7hU7lET_AIVRj6GBjssdhT2KPCS5RgUJX-BV28cX6VlM4ohF7R3WC9PP8IJEhCVLf7Trk2Ks-egIitISEDxGhSqzYK4ypEx-YUddpSvQXHkWgsm6A',
#                           'width': 4032}],
#               'place_id': 'ChIJTSNtN46AhYARJNR6k16Ff-0',
#               'plus_code': {'compound_code': 'QHPQ+R8 Lower Nob Hill, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHPQ+R8'},
#               'price_level': 2,
#               'rating': 2.8,
#               'reference': 'ChIJTSNtN46AhYARJNR6k16Ff-0',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '500 Geary St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7891465, 'lng': -122.418978},
#                            'viewport': {'northeast': {'lat': 37.79036447989272,
#                                                       'lng': -122.4176013701072},
#                                         'southwest': {'lat': 37.78766482010728,
#                                                       'lng': -122.4203010298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '3373f521b897e71d6d5188e75de2e458b1a4a147',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114223552321194732118/photos">Kizzie '
#                                                 'Pickens</a>'],
#                           'photo_reference': 'CmRaAAAAWvviQmXpe5EQAKeot2wiwsjw-Y6sMtC-MBaiLBFis-g_qUtt75gVtWY43RYrSzoCXD8W_vZp3sOCShXczMsutqgZpMhH2gpCY9sosF3jd9xOsnNP5St4c6w3QRRFjDxoEhAGxQMbveKJ5POIvNhdyugrGhRhfCuz-cl9q1y3g-_e4I4x9rNEDw',
#                           'width': 2048}],
#               'place_id': 'ChIJs9QKh5SAhYARWkpExiLww2I',
#               'plus_code': {'compound_code': 'QHQJ+MC Nob Hill, San Francisco, '
#                                              'CA',
#                             'global_code': '849VQHQJ+MC'},
#               'price_level': 2,
#               'rating': 3.7,
#               'reference': 'ChIJs9QKh5SAhYARWkpExiLww2I',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '1300 Bush St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.8060029, 'lng': -122.412655},
#                            'viewport': {'northeast': {'lat': 37.80723202989272,
#                                                       'lng': -122.4112804201073},
#                                         'southwest': {'lat': 37.80453237010727,
#                                                       'lng': -122.4139800798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'f9c020848f38a3898b9f5b62aae28a4df9a7e168',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1440,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111450706673730952587/photos">Albertino '
#                                                 'M.</a>'],
#                           'photo_reference': 'CmRaAAAAAv9lDnVbUM88qtODrPy6HW_ZMiR9VTDV2wOawBtH2iC7fez3vbi0vDpcj52-pnTPH_MrkzSuH1cefhqrfoJjHb-uFQuLDpU3uivYZVQntPciOUbJ5xL03ESiAaDRitiaEhDmNkm5_0uH5JBRJwaO9k1VGhT-wGsoDOv374ieXlQ1F86XsZk3xw',
#                           'width': 2560}],
#               'place_id': 'ChIJ2zA9M_uAhYARara-WV_WXZs',
#               'plus_code': {'compound_code': 'RH4P+CW North Beach, San '
#                                              'Francisco, CA',
#                             'global_code': '849VRH4P+CW'},
#               'price_level': 2,
#               'rating': 2.6,
#               'reference': 'ChIJ2zA9M_uAhYARara-WV_WXZs',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '320 Bay St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7910192, 'lng': -122.4205235},
#                            'viewport': {'northeast': {'lat': 37.79235212989272,
#                                                       'lng': -122.4193052701073},
#                                         'southwest': {'lat': 37.78965247010727,
#                                                       'lng': -122.4220049298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'abe68eddf6ae8ee545740a1796a0ebdc372501de',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109828960797220184151/photos">Avi '
#                                                 'R</a>'],
#                           'photo_reference': 'CmRaAAAA4lI9LQz-PE_JCWv11e7NYethE_ELCnChKaHAw9sGuRGMbrwooN0S8r2PsTOMdQ2TMP98mfuihIO4B2BDgwp0Rrm1BDmT8TCGoxTIXuaZHHE5BhemJlMmX_tMMwQpTP5uEhBAQonswTsF1nn31IdoGydYGhRcVrD0Su9HO5XUkl9NNdc6AoyhYA',
#                           'width': 3120}],
#               'place_id': 'ChIJ3RRpLeuAhYARaGG9CFc7LPY',
#               'plus_code': {'compound_code': 'QHRH+CQ Nob Hill, San Francisco, '
#                                              'CA',
#                             'global_code': '849VQHRH+CQ'},
#               'price_level': 2,
#               'rating': 4,
#               'reference': 'ChIJ3RRpLeuAhYARaGG9CFc7LPY',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '1524 Polk St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.7963865, 'lng': -122.4216403},
#                            'viewport': {'northeast': {'lat': 37.79772147989272,
#                                                       'lng': -122.4204015201072},
#                                         'southwest': {'lat': 37.79502182010727,
#                                                       'lng': -122.4231011798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'b4cdddf6551974f8277161ab5e0262fcb56314f5',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107602328530544278868/photos">Raymond '
#                                                 'Hamilton</a>'],
#                           'photo_reference': 'CmRaAAAAA1__gC9--K9PWATMSX78XmR6yjyzmZLB5FS1ZQlWfLyEBq3pZ8BGdKghxOlpt2jnQsYmDR4pHCPk_701Jio8IOWWqxYHw0_7YSHQqGoWe0t6kotg7-fCyr5A06-yF1KzEhAl-UL1D6xQs6zQD_77SLanGhTCIIkb9w9prFHk79RvzLhC9j1QPg',
#                           'width': 2048}],
#               'place_id': 'ChIJ3RRpLeuAhYARpI7aPCMX7-A',
#               'plus_code': {'compound_code': 'QHWH+H8 Russian Hill, San '
#                                              'Francisco, CA',
#                             'global_code': '849VQHWH+H8'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJ3RRpLeuAhYARpI7aPCMX7-A',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '2120 Polk St, San Francisco'},
#              {'geometry': {'location': {'lat': 37.8047319, 'lng': -122.4170817},
#                            'viewport': {'northeast': {'lat': 37.80617547989272,
#                                                       'lng': -122.4157694701073},
#                                         'southwest': {'lat': 37.80347582010728,
#                                                       'lng': -122.4184691298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '1f3c812cee669ad6fc1269dcf0554c3f749a52cb',
#               'name': 'Walgreens',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114315763380453729003/photos">Jean '
#                                                 'Vincent</a>'],
#                           'photo_reference': 'CmRaAAAAw6jVcKHpnh4ZDJ0RF3YQcrb5KseWmarHRBDR2pkxpWHVWcIVJbkbggHexoawMEXs2di6l0u_Nt-Sjc3FPkw2y2OLhVkOVCtTWFZyXRGZw-8NH3zArulK_YEvTUNtZQT3EhAvkw3TVSN87g2_t5p0Pga7GhS6F1LKyXBH086tJ_RaSv_SHjtn8Q',
#                           'width': 1620}],
#               'place_id': 'ChIJI7M4P-SAhYARx2WS_e0nvBI',
#               'plus_code': {'compound_code': 'RH3M+V5 Russian Hill, San '
#                                              'Francisco, CA',
#                             'global_code': '849VRH3M+V5'},
#               'price_level': 2,
#               'rating': 3.3,
#               'reference': 'ChIJI7M4P-SAhYARx2WS_e0nvBI',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'clothing_store',
#                         'store',
#                         'health',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '1175 Columbus Ave, San Francisco'}],
#  'status': 'OK'}

# %%
# Print the address of the closest Walgreens to campus
response['results'][0]['vicinity']
# Out:
# '88 Spear St, San Francisco'

# %%
# Read the stores.csv as a pandas dataframe
stores = pd.read_csv('./Resources/stores.csv')
stores.head()
# Out:
#   department stores
# 0            Macy's
# 1     Bloomingdales
# 2         Nordstrom
# 3              Ross
# 4         Marshalls

# %%
# Set up additional columns to hold information for address and rating
stores["address"] = ""
stores["rating"] = ""
stores.head()
# Out:
#   department stores address rating
# 0            Macy's
# 1     Bloomingdales
# 2         Nordstrom
# 3              Ross
# 4         Marshalls

# %%
# Create new parameters so that you are now searching for stores
# Use iterrows to iterate through the dataframe and add keywords to the new parameter
for index, row in stores.iterrows():
    params = {
    "keyword": row['department stores'],
    "type": 'store',
    "location": campus,
    "rankby": "distance",
    "key": gkey
    }
    
    # Assemble the url and make an API request
    response = requests.get(query_url, params = params).json()
    
    # Store the response results in the dataframe
    stores.loc[index, 'address'] = response['results'][0]['vicinity']
    stores.loc[index, 'rating'] = response['results'][0]['rating']
    
# Display the dataframe with newly added data
stores.head()
# Out:
#   department stores                         address rating
# 0            Macy's  120 Stockton St, San Francisco    3.8
# 1     Bloomingdales    845 Market St, San Francisco    4.1
# 2         Nordstrom    865 Market St, San Francisco    4.3
# 3              Ross    799 Market St, San Francisco    4.1
# 4         Marshalls    760 Market St, San Francisco      4
